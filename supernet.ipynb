# %% [markdown]
# # Little example on how the supernet works

# %%
import sys
import os


from ws_universale.nb201 import sample_nb201_networks
from ws_universale.supernet import Supernet

networks = sample_nb201_networks(N=1)

supernet = Supernet()
supernet.build(networks)
print(supernet)

supernet.summary()
# Out:
# Supernet(1 subnet note, 6 archi, 6 op totali)
# Supernet(1 subnet note, 6 archi, 6 op totali)
#   SuperEdge('0'→'1', MixedOp(['skip_connect']))
#   SuperEdge('0'→'2', MixedOp(['nor_conv_1x1']))
#   SuperEdge('1'→'2', MixedOp(['avg_pool3x3']))
#   SuperEdge('0'→'3', MixedOp(['nor_conv_1x1']))
#   SuperEdge('1'→'3', MixedOp(['none']))
#   SuperEdge('2'→'3', MixedOp(['skip_connect']))

# %% [markdown]
# watch as the supernet increase its size as new network are fed in

# %%
networks = sample_nb201_networks(N=1)
supernet.expand(networks)

supernet.summary()
# Out:
# Supernet(2 subnet note, 6 archi, 11 op totali)
#   SuperEdge('0'→'1', MixedOp(['skip_connect', 'none']))
#   SuperEdge('0'→'2', MixedOp(['nor_conv_1x1', 'none']))
#   SuperEdge('1'→'2', MixedOp(['avg_pool3x3', 'none']))
#   SuperEdge('0'→'3', MixedOp(['nor_conv_1x1', 'skip_connect']))
#   SuperEdge('1'→'3', MixedOp(['none', 'avg_pool3x3']))
#   SuperEdge('2'→'3', MixedOp(['skip_connect']))

# %%
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from utils_functions.utils import get_cifar10_loaders

train_loader, val_loader = get_cifar10_loaders(batch_size=256)
# Out:
# 100%|██████████| 170M/170M [05:53<00:00, 482kB/s]

# %% [markdown]
# this might take a while (approximatly 1 hour) but see how the supernet converges

# %%
import torch.nn as nn
import torch

supernet = Supernet()

population = sample_nb201_networks(N=256, seed=42)

accuracies = supernet.eval_subnets(
    networks      = population,
    train_loader  = train_loader,
    eval_loader   = val_loader,
    device        = "cuda",
    bn_batches    = 1024,
    epochs        = 120,
    calibrate     = True,
    M             = 1,
    criterion     = nn.CrossEntropyLoss(label_smoothing=0.1),
    use_label_smoothing = True,
    scheduler_factory   = lambda opt: torch.optim.lr_scheduler.CosineAnnealingLR(
        opt, T_max=200, eta_min=1e-4
    ),
    optimizer_factory   = lambda p: torch.optim.SGD(
        p, lr=0.025, momentum=0.9, weight_decay=3e-4, nesterov=True
    ),
)
# Out:
# Epoch   0 | Batch    0 | Loss (M=1): 2.2942 | LR: 0.025000 | Path noti: 254
# Epoch   0 | Batch   25 | Loss (M=1): 2.3058 | LR: 0.025000 | Path noti: 254
# Epoch   0 | Batch   50 | Loss (M=1): 2.1941 | LR: 0.025000 | Path noti: 254
# Epoch   0 | Batch   75 | Loss (M=1): 2.1829 | LR: 0.025000 | Path noti: 254
# Epoch   0 | Batch  100 | Loss (M=1): 2.2285 | LR: 0.025000 | Path noti: 254
# Epoch   0 | Batch  125 | Loss (M=1): 2.1312 | LR: 0.025000 | Path noti: 254
# Epoch   0 | Batch  150 | Loss (M=1): 2.1436 | LR: 0.025000 | Path noti: 254
# Epoch   0 | Batch  175 | Loss (M=1): 2.0960 | LR: 0.025000 | Path noti: 254
# Epoch   1 | Batch    0 | Loss (M=1): 2.1645 | LR: 0.024998 | Path noti: 254
# Epoch   1 | Batch   25 | Loss (M=1): 2.1424 | LR: 0.024998 | Path noti: 254
# Epoch   1 | Batch   50 | Loss (M=1): 2.0257 | LR: 0.024998 | Path noti: 254
# Epoch   1 | Batch   75 | Loss (M=1): 2.1721 | LR: 0.024998 | Path noti: 254
# Epoch   1 | Batch  100 | Loss (M=1): 2.1585 | LR: 0.024998 | Path noti: 254
# Epoch   1 | Batch  125 | Loss (M=1): 2.0038 | LR: 0.024998 | Path noti: 254
# Epoch   1 | Batch  150 | Loss (M=1): 2.1251 | LR: 0.024998 | Path noti: 254
# Epoch   1 | Batch  175 | Loss (M=1): 2.0883 | LR: 0.024998 | Path noti: 254
# Epoch   2 | Batch    0 | Loss (M=1): 1.9710 | LR: 0.024994 | Path noti: 254
# Epoch   2 | Batch   25 | Loss (M=1): 2.0675 | LR: 0.024994 | Path noti: 254
# Epoch   2 | Batch   50 | Loss (M=1): 1.9762 | LR: 0.024994 | Path noti: 254
# Epoch   2 | Batch   75 | Loss (M=1): 1.9805 | LR: 0.024994 | Path noti: 254
# Epoch   2 | Batch  100 | Loss (M=1): 2.0767 | LR: 0.024994 | Path noti: 254
# Epoch   2 | Batch  125 | Loss (M=1): 1.9323 | LR: 0.024994 | Path noti: 254
# Epoch   2 | Batch  150 | Loss (M=1): 1.9879 | LR: 0.024994 | Path noti: 254
# Epoch   2 | Batch  175 | Loss (M=1): 1.9598 | LR: 0.024994 | Path noti: 254
# Epoch   3 | Batch    0 | Loss (M=1): 1.9899 | LR: 0.024986 | Path noti: 254
# Epoch   3 | Batch   25 | Loss (M=1): 2.0074 | LR: 0.024986 | Path noti: 254
# Epoch   3 | Batch   50 | Loss (M=1): 1.9974 | LR: 0.024986 | Path noti: 254
# Epoch   3 | Batch   75 | Loss (M=1): 1.9525 | LR: 0.024986 | Path noti: 254
# Epoch   3 | Batch  100 | Loss (M=1): 2.1337 | LR: 0.024986 | Path noti: 254
# Epoch   3 | Batch  125 | Loss (M=1): 1.9766 | LR: 0.024986 | Path noti: 254
# Epoch   3 | Batch  150 | Loss (M=1): 1.9924 | LR: 0.024986 | Path noti: 254
# Epoch   3 | Batch  175 | Loss (M=1): 2.0210 | LR: 0.024986 | Path noti: 254
# Epoch   4 | Batch    0 | Loss (M=1): 1.8743 | LR: 0.024975 | Path noti: 254
# Epoch   4 | Batch   25 | Loss (M=1): 2.0879 | LR: 0.024975 | Path noti: 254
# Epoch   4 | Batch   50 | Loss (M=1): 1.9653 | LR: 0.024975 | Path noti: 254
# Epoch   4 | Batch   75 | Loss (M=1): 2.0414 | LR: 0.024975 | Path noti: 254
# Epoch   4 | Batch  100 | Loss (M=1): 1.9532 | LR: 0.024975 | Path noti: 254
# Epoch   4 | Batch  125 | Loss (M=1): 2.3064 | LR: 0.024975 | Path noti: 254
# Epoch   4 | Batch  150 | Loss (M=1): 2.1073 | LR: 0.024975 | Path noti: 254
# Epoch   4 | Batch  175 | Loss (M=1): 1.9579 | LR: 0.024975 | Path noti: 254
# Epoch   5 | Batch    0 | Loss (M=1): 2.1130 | LR: 0.024962 | Path noti: 254
# Epoch   5 | Batch   25 | Loss (M=1): 2.0084 | LR: 0.024962 | Path noti: 254
# Epoch   5 | Batch   50 | Loss (M=1): 2.0680 | LR: 0.024962 | Path noti: 254
# Epoch   5 | Batch   75 | Loss (M=1): 1.9912 | LR: 0.024962 | Path noti: 254
# Epoch   5 | Batch  100 | Loss (M=1): 1.9115 | LR: 0.024962 | Path noti: 254
# Epoch   5 | Batch  125 | Loss (M=1): 1.9287 | LR: 0.024962 | Path noti: 254
# Epoch   5 | Batch  150 | Loss (M=1): 1.9240 | LR: 0.024962 | Path noti: 254
# Epoch   5 | Batch  175 | Loss (M=1): 2.0030 | LR: 0.024962 | Path noti: 254
# Epoch   6 | Batch    0 | Loss (M=1): 1.9085 | LR: 0.024945 | Path noti: 254
# Epoch   6 | Batch   25 | Loss (M=1): 1.9847 | LR: 0.024945 | Path noti: 254
# Epoch   6 | Batch   50 | Loss (M=1): 1.9747 | LR: 0.024945 | Path noti: 254
# Epoch   6 | Batch   75 | Loss (M=1): 1.9036 | LR: 0.024945 | Path noti: 254
# Epoch   6 | Batch  100 | Loss (M=1): 1.8923 | LR: 0.024945 | Path noti: 254
# Epoch   6 | Batch  125 | Loss (M=1): 1.9349 | LR: 0.024945 | Path noti: 254
# Epoch   6 | Batch  150 | Loss (M=1): 1.8613 | LR: 0.024945 | Path noti: 254
# Epoch   6 | Batch  175 | Loss (M=1): 1.9764 | LR: 0.024945 | Path noti: 254
# Epoch   7 | Batch    0 | Loss (M=1): 1.9692 | LR: 0.024925 | Path noti: 254
# Epoch   7 | Batch   25 | Loss (M=1): 2.0058 | LR: 0.024925 | Path noti: 254
# Epoch   7 | Batch   50 | Loss (M=1): 1.8949 | LR: 0.024925 | Path noti: 254
# Epoch   7 | Batch   75 | Loss (M=1): 1.9838 | LR: 0.024925 | Path noti: 254
# Epoch   7 | Batch  100 | Loss (M=1): 2.0282 | LR: 0.024925 | Path noti: 254
# Epoch   7 | Batch  125 | Loss (M=1): 1.9155 | LR: 0.024925 | Path noti: 254
# Epoch   7 | Batch  150 | Loss (M=1): 2.0014 | LR: 0.024925 | Path noti: 254
# Epoch   7 | Batch  175 | Loss (M=1): 2.1278 | LR: 0.024925 | Path noti: 254
# Epoch   8 | Batch    0 | Loss (M=1): 1.8968 | LR: 0.024902 | Path noti: 254
# Epoch   8 | Batch   25 | Loss (M=1): 2.0421 | LR: 0.024902 | Path noti: 254
# Epoch   8 | Batch   50 | Loss (M=1): 1.9747 | LR: 0.024902 | Path noti: 254
# Epoch   8 | Batch   75 | Loss (M=1): 1.9286 | LR: 0.024902 | Path noti: 254
# Epoch   8 | Batch  100 | Loss (M=1): 1.9284 | LR: 0.024902 | Path noti: 254
# Epoch   8 | Batch  125 | Loss (M=1): 1.9266 | LR: 0.024902 | Path noti: 254
# Epoch   8 | Batch  150 | Loss (M=1): 1.9585 | LR: 0.024902 | Path noti: 254
# Epoch   8 | Batch  175 | Loss (M=1): 1.9829 | LR: 0.024902 | Path noti: 254
# Epoch   9 | Batch    0 | Loss (M=1): 1.9424 | LR: 0.024876 | Path noti: 254
# Epoch   9 | Batch   25 | Loss (M=1): 1.8545 | LR: 0.024876 | Path noti: 254
# Epoch   9 | Batch   50 | Loss (M=1): 2.0764 | LR: 0.024876 | Path noti: 254
# Epoch   9 | Batch   75 | Loss (M=1): 1.9259 | LR: 0.024876 | Path noti: 254
# Epoch   9 | Batch  100 | Loss (M=1): 1.8135 | LR: 0.024876 | Path noti: 254
# Epoch   9 | Batch  125 | Loss (M=1): 1.8230 | LR: 0.024876 | Path noti: 254
# Epoch   9 | Batch  150 | Loss (M=1): 1.8506 | LR: 0.024876 | Path noti: 254
# Epoch   9 | Batch  175 | Loss (M=1): 1.8922 | LR: 0.024876 | Path noti: 254
# Epoch  10 | Batch    0 | Loss (M=1): 2.1074 | LR: 0.024847 | Path noti: 254
# Epoch  10 | Batch   25 | Loss (M=1): 1.8867 | LR: 0.024847 | Path noti: 254
# Epoch  10 | Batch   50 | Loss (M=1): 1.9752 | LR: 0.024847 | Path noti: 254
# Epoch  10 | Batch   75 | Loss (M=1): 1.8583 | LR: 0.024847 | Path noti: 254
# Epoch  10 | Batch  100 | Loss (M=1): 1.8782 | LR: 0.024847 | Path noti: 254
# Epoch  10 | Batch  125 | Loss (M=1): 1.8299 | LR: 0.024847 | Path noti: 254
# Epoch  10 | Batch  150 | Loss (M=1): 1.9428 | LR: 0.024847 | Path noti: 254
# Epoch  10 | Batch  175 | Loss (M=1): 1.8720 | LR: 0.024847 | Path noti: 254
# Epoch  11 | Batch    0 | Loss (M=1): 1.8858 | LR: 0.024815 | Path noti: 254
# Epoch  11 | Batch   25 | Loss (M=1): 1.9163 | LR: 0.024815 | Path noti: 254
# Epoch  11 | Batch   50 | Loss (M=1): 2.0093 | LR: 0.024815 | Path noti: 254
# Epoch  11 | Batch   75 | Loss (M=1): 1.8588 | LR: 0.024815 | Path noti: 254
# Epoch  11 | Batch  100 | Loss (M=1): 1.9492 | LR: 0.024815 | Path noti: 254
# Epoch  11 | Batch  125 | Loss (M=1): 1.8341 | LR: 0.024815 | Path noti: 254
# Epoch  11 | Batch  150 | Loss (M=1): 1.8772 | LR: 0.024815 | Path noti: 254
# Epoch  11 | Batch  175 | Loss (M=1): 1.9615 | LR: 0.024815 | Path noti: 254
# Epoch  12 | Batch    0 | Loss (M=1): 1.8610 | LR: 0.024779 | Path noti: 254
# Epoch  12 | Batch   25 | Loss (M=1): 1.8589 | LR: 0.024779 | Path noti: 254
# Epoch  12 | Batch   50 | Loss (M=1): 1.9216 | LR: 0.024779 | Path noti: 254
# Epoch  12 | Batch   75 | Loss (M=1): 1.9248 | LR: 0.024779 | Path noti: 254
# Epoch  12 | Batch  100 | Loss (M=1): 1.8576 | LR: 0.024779 | Path noti: 254
# Epoch  12 | Batch  125 | Loss (M=1): 1.8633 | LR: 0.024779 | Path noti: 254
# Epoch  12 | Batch  150 | Loss (M=1): 1.9122 | LR: 0.024779 | Path noti: 254
# Epoch  12 | Batch  175 | Loss (M=1): 1.8826 | LR: 0.024779 | Path noti: 254
# Epoch  13 | Batch    0 | Loss (M=1): 2.0637 | LR: 0.024741 | Path noti: 254
# Epoch  13 | Batch   25 | Loss (M=1): 1.8773 | LR: 0.024741 | Path noti: 254
# Epoch  13 | Batch   50 | Loss (M=1): 1.9209 | LR: 0.024741 | Path noti: 254
# Epoch  13 | Batch   75 | Loss (M=1): 1.8923 | LR: 0.024741 | Path noti: 254
# Epoch  13 | Batch  100 | Loss (M=1): 1.9139 | LR: 0.024741 | Path noti: 254
# Epoch  13 | Batch  125 | Loss (M=1): 1.7922 | LR: 0.024741 | Path noti: 254
# Epoch  13 | Batch  150 | Loss (M=1): 1.9057 | LR: 0.024741 | Path noti: 254
# Epoch  13 | Batch  175 | Loss (M=1): 1.9088 | LR: 0.024741 | Path noti: 254
# Epoch  14 | Batch    0 | Loss (M=1): 1.8513 | LR: 0.024700 | Path noti: 254
# Epoch  14 | Batch   25 | Loss (M=1): 1.8780 | LR: 0.024700 | Path noti: 254
# Epoch  14 | Batch   50 | Loss (M=1): 1.8889 | LR: 0.024700 | Path noti: 254
# Epoch  14 | Batch   75 | Loss (M=1): 2.0908 | LR: 0.024700 | Path noti: 254
# Epoch  14 | Batch  100 | Loss (M=1): 1.8561 | LR: 0.024700 | Path noti: 254
# Epoch  14 | Batch  125 | Loss (M=1): 1.8695 | LR: 0.024700 | Path noti: 254
# Epoch  14 | Batch  150 | Loss (M=1): 1.8644 | LR: 0.024700 | Path noti: 254
# Epoch  14 | Batch  175 | Loss (M=1): 1.8582 | LR: 0.024700 | Path noti: 254
# Epoch  15 | Batch    0 | Loss (M=1): 1.9660 | LR: 0.024656 | Path noti: 254
# Epoch  15 | Batch   25 | Loss (M=1): 1.8784 | LR: 0.024656 | Path noti: 254
# Epoch  15 | Batch   50 | Loss (M=1): 1.9848 | LR: 0.024656 | Path noti: 254
# Epoch  15 | Batch   75 | Loss (M=1): 1.8823 | LR: 0.024656 | Path noti: 254
# Epoch  15 | Batch  100 | Loss (M=1): 1.9320 | LR: 0.024656 | Path noti: 254
# Epoch  15 | Batch  125 | Loss (M=1): 1.8539 | LR: 0.024656 | Path noti: 254
# Epoch  15 | Batch  150 | Loss (M=1): 1.8813 | LR: 0.024656 | Path noti: 254
# Epoch  15 | Batch  175 | Loss (M=1): 1.9070 | LR: 0.024656 | Path noti: 254
# Epoch  16 | Batch    0 | Loss (M=1): 1.8068 | LR: 0.024609 | Path noti: 254
# Epoch  16 | Batch   25 | Loss (M=1): 1.8047 | LR: 0.024609 | Path noti: 254
# Epoch  16 | Batch   50 | Loss (M=1): 1.8097 | LR: 0.024609 | Path noti: 254
# Epoch  16 | Batch   75 | Loss (M=1): 1.8529 | LR: 0.024609 | Path noti: 254
# Epoch  16 | Batch  100 | Loss (M=1): 1.8536 | LR: 0.024609 | Path noti: 254
# Epoch  16 | Batch  125 | Loss (M=1): 1.7616 | LR: 0.024609 | Path noti: 254
# Epoch  16 | Batch  150 | Loss (M=1): 1.8901 | LR: 0.024609 | Path noti: 254
# Epoch  16 | Batch  175 | Loss (M=1): 1.9200 | LR: 0.024609 | Path noti: 254
# Epoch  17 | Batch    0 | Loss (M=1): 2.0059 | LR: 0.024559 | Path noti: 254
# Epoch  17 | Batch   25 | Loss (M=1): 1.8740 | LR: 0.024559 | Path noti: 254
# Epoch  17 | Batch   50 | Loss (M=1): 2.0016 | LR: 0.024559 | Path noti: 254
# Epoch  17 | Batch   75 | Loss (M=1): 2.0802 | LR: 0.024559 | Path noti: 254
# Epoch  17 | Batch  100 | Loss (M=1): 1.9132 | LR: 0.024559 | Path noti: 254
# Epoch  17 | Batch  125 | Loss (M=1): 1.8422 | LR: 0.024559 | Path noti: 254
# Epoch  17 | Batch  150 | Loss (M=1): 1.9506 | LR: 0.024559 | Path noti: 254
# Epoch  17 | Batch  175 | Loss (M=1): 2.0078 | LR: 0.024559 | Path noti: 254
# Epoch  18 | Batch    0 | Loss (M=1): 1.8504 | LR: 0.024506 | Path noti: 254
# Epoch  18 | Batch   25 | Loss (M=1): 1.8269 | LR: 0.024506 | Path noti: 254
# Epoch  18 | Batch   50 | Loss (M=1): 2.0445 | LR: 0.024506 | Path noti: 254
# Epoch  18 | Batch   75 | Loss (M=1): 1.9558 | LR: 0.024506 | Path noti: 254
# Epoch  18 | Batch  100 | Loss (M=1): 1.8363 | LR: 0.024506 | Path noti: 254
# Epoch  18 | Batch  125 | Loss (M=1): 1.9495 | LR: 0.024506 | Path noti: 254
# Epoch  18 | Batch  150 | Loss (M=1): 1.8256 | LR: 0.024506 | Path noti: 254
# Epoch  18 | Batch  175 | Loss (M=1): 1.9086 | LR: 0.024506 | Path noti: 254
# Epoch  19 | Batch    0 | Loss (M=1): 1.7267 | LR: 0.024450 | Path noti: 254
# Epoch  19 | Batch   25 | Loss (M=1): 1.8588 | LR: 0.024450 | Path noti: 254
# Epoch  19 | Batch   50 | Loss (M=1): 1.7454 | LR: 0.024450 | Path noti: 254
# Epoch  19 | Batch   75 | Loss (M=1): 1.8739 | LR: 0.024450 | Path noti: 254
# Epoch  19 | Batch  100 | Loss (M=1): 2.0367 | LR: 0.024450 | Path noti: 254
# Epoch  19 | Batch  125 | Loss (M=1): 1.9800 | LR: 0.024450 | Path noti: 254
# Epoch  19 | Batch  150 | Loss (M=1): 1.8430 | LR: 0.024450 | Path noti: 254
# Epoch  19 | Batch  175 | Loss (M=1): 1.8464 | LR: 0.024450 | Path noti: 254
# Epoch  20 | Batch    0 | Loss (M=1): 1.8346 | LR: 0.024391 | Path noti: 254
# Epoch  20 | Batch   25 | Loss (M=1): 1.8413 | LR: 0.024391 | Path noti: 254
# Epoch  20 | Batch   50 | Loss (M=1): 1.8943 | LR: 0.024391 | Path noti: 254
# Epoch  20 | Batch   75 | Loss (M=1): 1.8463 | LR: 0.024391 | Path noti: 254
# Epoch  20 | Batch  100 | Loss (M=1): 2.0601 | LR: 0.024391 | Path noti: 254
# Epoch  20 | Batch  125 | Loss (M=1): 1.8757 | LR: 0.024391 | Path noti: 254
# Epoch  20 | Batch  150 | Loss (M=1): 1.8898 | LR: 0.024391 | Path noti: 254
# Epoch  20 | Batch  175 | Loss (M=1): 1.8982 | LR: 0.024391 | Path noti: 254
# Epoch  21 | Batch    0 | Loss (M=1): 1.8317 | LR: 0.024329 | Path noti: 254
# Epoch  21 | Batch   25 | Loss (M=1): 1.9069 | LR: 0.024329 | Path noti: 254
# Epoch  21 | Batch   50 | Loss (M=1): 1.8278 | LR: 0.024329 | Path noti: 254
# Epoch  21 | Batch   75 | Loss (M=1): 1.9263 | LR: 0.024329 | Path noti: 254
# Epoch  21 | Batch  100 | Loss (M=1): 1.9267 | LR: 0.024329 | Path noti: 254
# Epoch  21 | Batch  125 | Loss (M=1): 2.0236 | LR: 0.024329 | Path noti: 254
# Epoch  21 | Batch  150 | Loss (M=1): 1.8098 | LR: 0.024329 | Path noti: 254
# Epoch  21 | Batch  175 | Loss (M=1): 1.9061 | LR: 0.024329 | Path noti: 254
# Epoch  22 | Batch    0 | Loss (M=1): 1.8282 | LR: 0.024264 | Path noti: 254
# Epoch  22 | Batch   25 | Loss (M=1): 1.9138 | LR: 0.024264 | Path noti: 254
# Epoch  22 | Batch   50 | Loss (M=1): 1.7838 | LR: 0.024264 | Path noti: 254
# Epoch  22 | Batch   75 | Loss (M=1): 1.7902 | LR: 0.024264 | Path noti: 254
# Epoch  22 | Batch  100 | Loss (M=1): 1.9430 | LR: 0.024264 | Path noti: 254
# Epoch  22 | Batch  125 | Loss (M=1): 1.8299 | LR: 0.024264 | Path noti: 254
# Epoch  22 | Batch  150 | Loss (M=1): 1.7186 | LR: 0.024264 | Path noti: 254
# Epoch  22 | Batch  175 | Loss (M=1): 1.8045 | LR: 0.024264 | Path noti: 254
# Epoch  23 | Batch    0 | Loss (M=1): 1.8568 | LR: 0.024196 | Path noti: 254
# Epoch  23 | Batch   25 | Loss (M=1): 1.8210 | LR: 0.024196 | Path noti: 254
# Epoch  23 | Batch   50 | Loss (M=1): 2.0459 | LR: 0.024196 | Path noti: 254
# Epoch  23 | Batch   75 | Loss (M=1): 1.8156 | LR: 0.024196 | Path noti: 254
# Epoch  23 | Batch  100 | Loss (M=1): 1.7611 | LR: 0.024196 | Path noti: 254
# Epoch  23 | Batch  125 | Loss (M=1): 1.8835 | LR: 0.024196 | Path noti: 254
# Epoch  23 | Batch  150 | Loss (M=1): 1.9112 | LR: 0.024196 | Path noti: 254
# Epoch  23 | Batch  175 | Loss (M=1): 1.8443 | LR: 0.024196 | Path noti: 254
# Epoch  24 | Batch    0 | Loss (M=1): 1.8667 | LR: 0.024126 | Path noti: 254
# Epoch  24 | Batch   25 | Loss (M=1): 1.8403 | LR: 0.024126 | Path noti: 254
# Epoch  24 | Batch   50 | Loss (M=1): 1.8043 | LR: 0.024126 | Path noti: 254
# Epoch  24 | Batch   75 | Loss (M=1): 1.8946 | LR: 0.024126 | Path noti: 254
# Epoch  24 | Batch  100 | Loss (M=1): 1.9064 | LR: 0.024126 | Path noti: 254
# Epoch  24 | Batch  125 | Loss (M=1): 1.9409 | LR: 0.024126 | Path noti: 254
# Epoch  24 | Batch  150 | Loss (M=1): 1.7847 | LR: 0.024126 | Path noti: 254
# Epoch  24 | Batch  175 | Loss (M=1): 2.3074 | LR: 0.024126 | Path noti: 254
# Epoch  25 | Batch    0 | Loss (M=1): 1.8467 | LR: 0.024052 | Path noti: 254
# Epoch  25 | Batch   25 | Loss (M=1): 1.8075 | LR: 0.024052 | Path noti: 254
# Epoch  25 | Batch   50 | Loss (M=1): 1.8889 | LR: 0.024052 | Path noti: 254
# Epoch  25 | Batch   75 | Loss (M=1): 1.9961 | LR: 0.024052 | Path noti: 254
# Epoch  25 | Batch  100 | Loss (M=1): 2.0353 | LR: 0.024052 | Path noti: 254
# Epoch  25 | Batch  125 | Loss (M=1): 1.8444 | LR: 0.024052 | Path noti: 254
# Epoch  25 | Batch  150 | Loss (M=1): 1.7448 | LR: 0.024052 | Path noti: 254
# Epoch  25 | Batch  175 | Loss (M=1): 1.8775 | LR: 0.024052 | Path noti: 254
# Epoch  26 | Batch    0 | Loss (M=1): 1.9138 | LR: 0.023976 | Path noti: 254
# Epoch  26 | Batch   25 | Loss (M=1): 1.9184 | LR: 0.023976 | Path noti: 254
# Epoch  26 | Batch   50 | Loss (M=1): 2.0748 | LR: 0.023976 | Path noti: 254
# Epoch  26 | Batch   75 | Loss (M=1): 1.8401 | LR: 0.023976 | Path noti: 254
# Epoch  26 | Batch  100 | Loss (M=1): 1.8564 | LR: 0.023976 | Path noti: 254
# Epoch  26 | Batch  125 | Loss (M=1): 1.8684 | LR: 0.023976 | Path noti: 254
# Epoch  26 | Batch  150 | Loss (M=1): 1.7924 | LR: 0.023976 | Path noti: 254
# Epoch  26 | Batch  175 | Loss (M=1): 1.8705 | LR: 0.023976 | Path noti: 254
# Epoch  27 | Batch    0 | Loss (M=1): 1.8421 | LR: 0.023897 | Path noti: 254
# Epoch  27 | Batch   25 | Loss (M=1): 1.9156 | LR: 0.023897 | Path noti: 254
# Epoch  27 | Batch   50 | Loss (M=1): 1.8625 | LR: 0.023897 | Path noti: 254
# Epoch  27 | Batch   75 | Loss (M=1): 1.8475 | LR: 0.023897 | Path noti: 254
# Epoch  27 | Batch  100 | Loss (M=1): 1.9531 | LR: 0.023897 | Path noti: 254
# Epoch  27 | Batch  125 | Loss (M=1): 1.9216 | LR: 0.023897 | Path noti: 254
# Epoch  27 | Batch  150 | Loss (M=1): 1.8980 | LR: 0.023897 | Path noti: 254
# Epoch  27 | Batch  175 | Loss (M=1): 1.8717 | LR: 0.023897 | Path noti: 254
# Epoch  28 | Batch    0 | Loss (M=1): 1.7787 | LR: 0.023815 | Path noti: 254
# Epoch  28 | Batch   25 | Loss (M=1): 1.8436 | LR: 0.023815 | Path noti: 254
# Epoch  28 | Batch   50 | Loss (M=1): 1.9155 | LR: 0.023815 | Path noti: 254
# Epoch  28 | Batch   75 | Loss (M=1): 1.7156 | LR: 0.023815 | Path noti: 254
# Epoch  28 | Batch  100 | Loss (M=1): 1.9136 | LR: 0.023815 | Path noti: 254
# Epoch  28 | Batch  125 | Loss (M=1): 2.0177 | LR: 0.023815 | Path noti: 254
# Epoch  28 | Batch  150 | Loss (M=1): 1.9405 | LR: 0.023815 | Path noti: 254
# Epoch  28 | Batch  175 | Loss (M=1): 2.0309 | LR: 0.023815 | Path noti: 254
# Epoch  29 | Batch    0 | Loss (M=1): 1.8034 | LR: 0.023730 | Path noti: 254
# Epoch  29 | Batch   25 | Loss (M=1): 1.8606 | LR: 0.023730 | Path noti: 254
# Epoch  29 | Batch   50 | Loss (M=1): 1.8239 | LR: 0.023730 | Path noti: 254
# Epoch  29 | Batch   75 | Loss (M=1): 1.8969 | LR: 0.023730 | Path noti: 254
# Epoch  29 | Batch  100 | Loss (M=1): 1.8023 | LR: 0.023730 | Path noti: 254
# Epoch  29 | Batch  125 | Loss (M=1): 1.9370 | LR: 0.023730 | Path noti: 254
# Epoch  29 | Batch  150 | Loss (M=1): 1.7433 | LR: 0.023730 | Path noti: 254
# Epoch  29 | Batch  175 | Loss (M=1): 1.8342 | LR: 0.023730 | Path noti: 254
# Epoch  30 | Batch    0 | Loss (M=1): 1.7717 | LR: 0.023643 | Path noti: 254
# Epoch  30 | Batch   25 | Loss (M=1): 1.9406 | LR: 0.023643 | Path noti: 254
# Epoch  30 | Batch   50 | Loss (M=1): 1.8832 | LR: 0.023643 | Path noti: 254
# Epoch  30 | Batch   75 | Loss (M=1): 1.8197 | LR: 0.023643 | Path noti: 254
# Epoch  30 | Batch  100 | Loss (M=1): 1.8913 | LR: 0.023643 | Path noti: 254
# Epoch  30 | Batch  125 | Loss (M=1): 1.7866 | LR: 0.023643 | Path noti: 254
# Epoch  30 | Batch  150 | Loss (M=1): 1.8033 | LR: 0.023643 | Path noti: 254
# Epoch  30 | Batch  175 | Loss (M=1): 1.8599 | LR: 0.023643 | Path noti: 254
# Epoch  31 | Batch    0 | Loss (M=1): 1.9381 | LR: 0.023553 | Path noti: 254
# Epoch  31 | Batch   25 | Loss (M=1): 1.8351 | LR: 0.023553 | Path noti: 254
# Epoch  31 | Batch   50 | Loss (M=1): 1.8801 | LR: 0.023553 | Path noti: 254
# Epoch  31 | Batch   75 | Loss (M=1): 1.8838 | LR: 0.023553 | Path noti: 254
# Epoch  31 | Batch  100 | Loss (M=1): 1.7958 | LR: 0.023553 | Path noti: 254
# Epoch  31 | Batch  125 | Loss (M=1): 1.8199 | LR: 0.023553 | Path noti: 254
# Epoch  31 | Batch  150 | Loss (M=1): 1.8727 | LR: 0.023553 | Path noti: 254
# Epoch  31 | Batch  175 | Loss (M=1): 2.0561 | LR: 0.023553 | Path noti: 254
# Epoch  32 | Batch    0 | Loss (M=1): 1.8494 | LR: 0.023460 | Path noti: 254
# Epoch  32 | Batch   25 | Loss (M=1): 2.0555 | LR: 0.023460 | Path noti: 254
# Epoch  32 | Batch   50 | Loss (M=1): 1.7285 | LR: 0.023460 | Path noti: 254
# Epoch  32 | Batch   75 | Loss (M=1): 1.9427 | LR: 0.023460 | Path noti: 254
# Epoch  32 | Batch  100 | Loss (M=1): 1.8954 | LR: 0.023460 | Path noti: 254
# Epoch  32 | Batch  125 | Loss (M=1): 1.8417 | LR: 0.023460 | Path noti: 254
# Epoch  32 | Batch  150 | Loss (M=1): 1.7254 | LR: 0.023460 | Path noti: 254
# Epoch  32 | Batch  175 | Loss (M=1): 2.0267 | LR: 0.023460 | Path noti: 254
# Epoch  33 | Batch    0 | Loss (M=1): 1.8809 | LR: 0.023364 | Path noti: 254
# Epoch  33 | Batch   25 | Loss (M=1): 1.7466 | LR: 0.023364 | Path noti: 254
# Epoch  33 | Batch   50 | Loss (M=1): 1.8493 | LR: 0.023364 | Path noti: 254
# Epoch  33 | Batch   75 | Loss (M=1): 1.8730 | LR: 0.023364 | Path noti: 254
# Epoch  33 | Batch  100 | Loss (M=1): 1.7751 | LR: 0.023364 | Path noti: 254
# Epoch  33 | Batch  125 | Loss (M=1): 1.8594 | LR: 0.023364 | Path noti: 254
# Epoch  33 | Batch  150 | Loss (M=1): 1.8001 | LR: 0.023364 | Path noti: 254
# Epoch  33 | Batch  175 | Loss (M=1): 1.6724 | LR: 0.023364 | Path noti: 254
# Epoch  34 | Batch    0 | Loss (M=1): 1.7467 | LR: 0.023266 | Path noti: 254
# Epoch  34 | Batch   25 | Loss (M=1): 1.7483 | LR: 0.023266 | Path noti: 254
# Epoch  34 | Batch   50 | Loss (M=1): 1.8192 | LR: 0.023266 | Path noti: 254
# Epoch  34 | Batch   75 | Loss (M=1): 1.9224 | LR: 0.023266 | Path noti: 254
# Epoch  34 | Batch  100 | Loss (M=1): 1.8369 | LR: 0.023266 | Path noti: 254
# Epoch  34 | Batch  125 | Loss (M=1): 1.7655 | LR: 0.023266 | Path noti: 254
# Epoch  34 | Batch  150 | Loss (M=1): 1.8400 | LR: 0.023266 | Path noti: 254
# Epoch  34 | Batch  175 | Loss (M=1): 1.7174 | LR: 0.023266 | Path noti: 254
# Epoch  35 | Batch    0 | Loss (M=1): 1.8054 | LR: 0.023165 | Path noti: 254
# Epoch  35 | Batch   25 | Loss (M=1): 1.8024 | LR: 0.023165 | Path noti: 254
# Epoch  35 | Batch   50 | Loss (M=1): 1.7042 | LR: 0.023165 | Path noti: 254
# Epoch  35 | Batch   75 | Loss (M=1): 1.8478 | LR: 0.023165 | Path noti: 254
# Epoch  35 | Batch  100 | Loss (M=1): 1.8113 | LR: 0.023165 | Path noti: 254
# Epoch  35 | Batch  125 | Loss (M=1): 1.8595 | LR: 0.023165 | Path noti: 254
# Epoch  35 | Batch  150 | Loss (M=1): 1.8007 | LR: 0.023165 | Path noti: 254
# Epoch  35 | Batch  175 | Loss (M=1): 1.8685 | LR: 0.023165 | Path noti: 254
# Epoch  36 | Batch    0 | Loss (M=1): 1.8274 | LR: 0.023062 | Path noti: 254
# Epoch  36 | Batch   25 | Loss (M=1): 1.6856 | LR: 0.023062 | Path noti: 254
# Epoch  36 | Batch   50 | Loss (M=1): 1.9278 | LR: 0.023062 | Path noti: 254
# Epoch  36 | Batch   75 | Loss (M=1): 1.8163 | LR: 0.023062 | Path noti: 254
# Epoch  36 | Batch  100 | Loss (M=1): 1.7584 | LR: 0.023062 | Path noti: 254
# Epoch  36 | Batch  125 | Loss (M=1): 1.7939 | LR: 0.023062 | Path noti: 254
# Epoch  36 | Batch  150 | Loss (M=1): 1.7296 | LR: 0.023062 | Path noti: 254
# Epoch  36 | Batch  175 | Loss (M=1): 1.8671 | LR: 0.023062 | Path noti: 254
# Epoch  37 | Batch    0 | Loss (M=1): 1.8796 | LR: 0.022956 | Path noti: 254
# Epoch  37 | Batch   25 | Loss (M=1): 1.8010 | LR: 0.022956 | Path noti: 254
# Epoch  37 | Batch   50 | Loss (M=1): 1.8249 | LR: 0.022956 | Path noti: 254
# Epoch  37 | Batch   75 | Loss (M=1): 1.8805 | LR: 0.022956 | Path noti: 254
# Epoch  37 | Batch  100 | Loss (M=1): 1.8086 | LR: 0.022956 | Path noti: 254
# Epoch  37 | Batch  125 | Loss (M=1): 1.7785 | LR: 0.022956 | Path noti: 254
# Epoch  37 | Batch  150 | Loss (M=1): 1.8830 | LR: 0.022956 | Path noti: 254
# Epoch  37 | Batch  175 | Loss (M=1): 1.7363 | LR: 0.022956 | Path noti: 254
# Epoch  38 | Batch    0 | Loss (M=1): 1.7833 | LR: 0.022847 | Path noti: 254
# Epoch  38 | Batch   25 | Loss (M=1): 1.8693 | LR: 0.022847 | Path noti: 254
# Epoch  38 | Batch   50 | Loss (M=1): 1.7933 | LR: 0.022847 | Path noti: 254
# Epoch  38 | Batch   75 | Loss (M=1): 1.8874 | LR: 0.022847 | Path noti: 254
# Epoch  38 | Batch  100 | Loss (M=1): 1.9067 | LR: 0.022847 | Path noti: 254
# Epoch  38 | Batch  125 | Loss (M=1): 1.7344 | LR: 0.022847 | Path noti: 254
# Epoch  38 | Batch  150 | Loss (M=1): 1.7839 | LR: 0.022847 | Path noti: 254
# Epoch  38 | Batch  175 | Loss (M=1): 1.9420 | LR: 0.022847 | Path noti: 254
# Epoch  39 | Batch    0 | Loss (M=1): 1.7529 | LR: 0.022736 | Path noti: 254
# Epoch  39 | Batch   25 | Loss (M=1): 1.9379 | LR: 0.022736 | Path noti: 254
# Epoch  39 | Batch   50 | Loss (M=1): 1.9006 | LR: 0.022736 | Path noti: 254
# Epoch  39 | Batch   75 | Loss (M=1): 1.9097 | LR: 0.022736 | Path noti: 254
# Epoch  39 | Batch  100 | Loss (M=1): 1.8879 | LR: 0.022736 | Path noti: 254
# Epoch  39 | Batch  125 | Loss (M=1): 1.8639 | LR: 0.022736 | Path noti: 254
# Epoch  39 | Batch  150 | Loss (M=1): 1.6937 | LR: 0.022736 | Path noti: 254
# Epoch  39 | Batch  175 | Loss (M=1): 1.8734 | LR: 0.022736 | Path noti: 254
# Epoch  40 | Batch    0 | Loss (M=1): 1.9032 | LR: 0.022622 | Path noti: 254
# Epoch  40 | Batch   25 | Loss (M=1): 1.8257 | LR: 0.022622 | Path noti: 254
# Epoch  40 | Batch   50 | Loss (M=1): 1.8585 | LR: 0.022622 | Path noti: 254
# Epoch  40 | Batch   75 | Loss (M=1): 1.6935 | LR: 0.022622 | Path noti: 254
# Epoch  40 | Batch  100 | Loss (M=1): 1.8138 | LR: 0.022622 | Path noti: 254
# Epoch  40 | Batch  125 | Loss (M=1): 1.8944 | LR: 0.022622 | Path noti: 254
# Epoch  40 | Batch  150 | Loss (M=1): 1.8544 | LR: 0.022622 | Path noti: 254
# Epoch  40 | Batch  175 | Loss (M=1): 1.7462 | LR: 0.022622 | Path noti: 254
# Epoch  41 | Batch    0 | Loss (M=1): 1.7997 | LR: 0.022506 | Path noti: 254
# Epoch  41 | Batch   25 | Loss (M=1): 1.7609 | LR: 0.022506 | Path noti: 254
# Epoch  41 | Batch   50 | Loss (M=1): 1.7056 | LR: 0.022506 | Path noti: 254
# Epoch  41 | Batch   75 | Loss (M=1): 1.8018 | LR: 0.022506 | Path noti: 254
# Epoch  41 | Batch  100 | Loss (M=1): 1.8491 | LR: 0.022506 | Path noti: 254
# Epoch  41 | Batch  125 | Loss (M=1): 1.9455 | LR: 0.022506 | Path noti: 254
# Epoch  41 | Batch  150 | Loss (M=1): 1.7937 | LR: 0.022506 | Path noti: 254
# Epoch  41 | Batch  175 | Loss (M=1): 1.7038 | LR: 0.022506 | Path noti: 254
# Epoch  42 | Batch    0 | Loss (M=1): 1.8346 | LR: 0.022387 | Path noti: 254
# Epoch  42 | Batch   25 | Loss (M=1): 1.8989 | LR: 0.022387 | Path noti: 254
# Epoch  42 | Batch   50 | Loss (M=1): 1.7431 | LR: 0.022387 | Path noti: 254
# Epoch  42 | Batch   75 | Loss (M=1): 1.8993 | LR: 0.022387 | Path noti: 254
# Epoch  42 | Batch  100 | Loss (M=1): 1.7880 | LR: 0.022387 | Path noti: 254
# Epoch  42 | Batch  125 | Loss (M=1): 1.8668 | LR: 0.022387 | Path noti: 254
# Epoch  42 | Batch  150 | Loss (M=1): 1.6505 | LR: 0.022387 | Path noti: 254
# Epoch  42 | Batch  175 | Loss (M=1): 1.9833 | LR: 0.022387 | Path noti: 254
# Epoch  43 | Batch    0 | Loss (M=1): 1.8358 | LR: 0.022266 | Path noti: 254
# Epoch  43 | Batch   25 | Loss (M=1): 1.8752 | LR: 0.022266 | Path noti: 254
# Epoch  43 | Batch   50 | Loss (M=1): 1.8613 | LR: 0.022266 | Path noti: 254
# Epoch  43 | Batch   75 | Loss (M=1): 1.8389 | LR: 0.022266 | Path noti: 254
# Epoch  43 | Batch  100 | Loss (M=1): 2.0275 | LR: 0.022266 | Path noti: 254
# Epoch  43 | Batch  125 | Loss (M=1): 1.8613 | LR: 0.022266 | Path noti: 254
# Epoch  43 | Batch  150 | Loss (M=1): 2.0189 | LR: 0.022266 | Path noti: 254
# Epoch  43 | Batch  175 | Loss (M=1): 1.9614 | LR: 0.022266 | Path noti: 254
# Epoch  44 | Batch    0 | Loss (M=1): 1.6603 | LR: 0.022143 | Path noti: 254
# Epoch  44 | Batch   25 | Loss (M=1): 1.7403 | LR: 0.022143 | Path noti: 254
# Epoch  44 | Batch   50 | Loss (M=1): 1.7496 | LR: 0.022143 | Path noti: 254
# Epoch  44 | Batch   75 | Loss (M=1): 1.7728 | LR: 0.022143 | Path noti: 254
# Epoch  44 | Batch  100 | Loss (M=1): 1.8195 | LR: 0.022143 | Path noti: 254
# Epoch  44 | Batch  125 | Loss (M=1): 1.9083 | LR: 0.022143 | Path noti: 254
# Epoch  44 | Batch  150 | Loss (M=1): 2.0536 | LR: 0.022143 | Path noti: 254
# Epoch  44 | Batch  175 | Loss (M=1): 1.8267 | LR: 0.022143 | Path noti: 254
# Epoch  45 | Batch    0 | Loss (M=1): 1.9240 | LR: 0.022017 | Path noti: 254
# Epoch  45 | Batch   25 | Loss (M=1): 1.8175 | LR: 0.022017 | Path noti: 254
# Epoch  45 | Batch   50 | Loss (M=1): 1.8968 | LR: 0.022017 | Path noti: 254
# Epoch  45 | Batch   75 | Loss (M=1): 1.8141 | LR: 0.022017 | Path noti: 254
# Epoch  45 | Batch  100 | Loss (M=1): 1.8242 | LR: 0.022017 | Path noti: 254
# Epoch  45 | Batch  125 | Loss (M=1): 1.8587 | LR: 0.022017 | Path noti: 254
# Epoch  45 | Batch  150 | Loss (M=1): 1.9339 | LR: 0.022017 | Path noti: 254
# Epoch  45 | Batch  175 | Loss (M=1): 2.0544 | LR: 0.022017 | Path noti: 254
# Epoch  46 | Batch    0 | Loss (M=1): 1.8585 | LR: 0.021889 | Path noti: 254
# Epoch  46 | Batch   25 | Loss (M=1): 1.9012 | LR: 0.021889 | Path noti: 254
# Epoch  46 | Batch   50 | Loss (M=1): 1.7617 | LR: 0.021889 | Path noti: 254
# Epoch  46 | Batch   75 | Loss (M=1): 1.7227 | LR: 0.021889 | Path noti: 254
# Epoch  46 | Batch  100 | Loss (M=1): 1.7915 | LR: 0.021889 | Path noti: 254
# Epoch  46 | Batch  125 | Loss (M=1): 2.0198 | LR: 0.021889 | Path noti: 254
# Epoch  46 | Batch  150 | Loss (M=1): 1.8359 | LR: 0.021889 | Path noti: 254
# Epoch  46 | Batch  175 | Loss (M=1): 1.9110 | LR: 0.021889 | Path noti: 254
# Epoch  47 | Batch    0 | Loss (M=1): 1.7840 | LR: 0.021758 | Path noti: 254
# Epoch  47 | Batch   25 | Loss (M=1): 1.9021 | LR: 0.021758 | Path noti: 254
# Epoch  47 | Batch   50 | Loss (M=1): 1.7584 | LR: 0.021758 | Path noti: 254
# Epoch  47 | Batch   75 | Loss (M=1): 1.8804 | LR: 0.021758 | Path noti: 254
# Epoch  47 | Batch  100 | Loss (M=1): 1.7826 | LR: 0.021758 | Path noti: 254
# Epoch  47 | Batch  125 | Loss (M=1): 1.8580 | LR: 0.021758 | Path noti: 254
# Epoch  47 | Batch  150 | Loss (M=1): 1.8323 | LR: 0.021758 | Path noti: 254
# Epoch  47 | Batch  175 | Loss (M=1): 1.7933 | LR: 0.021758 | Path noti: 254
# Epoch  48 | Batch    0 | Loss (M=1): 1.8372 | LR: 0.021626 | Path noti: 254
# Epoch  48 | Batch   25 | Loss (M=1): 1.6954 | LR: 0.021626 | Path noti: 254
# Epoch  48 | Batch   50 | Loss (M=1): 1.6913 | LR: 0.021626 | Path noti: 254
# Epoch  48 | Batch   75 | Loss (M=1): 1.7837 | LR: 0.021626 | Path noti: 254
# Epoch  48 | Batch  100 | Loss (M=1): 1.6948 | LR: 0.021626 | Path noti: 254
# Epoch  48 | Batch  125 | Loss (M=1): 1.9532 | LR: 0.021626 | Path noti: 254
# Epoch  48 | Batch  150 | Loss (M=1): 1.7586 | LR: 0.021626 | Path noti: 254
# Epoch  48 | Batch  175 | Loss (M=1): 1.8599 | LR: 0.021626 | Path noti: 254
# Epoch  49 | Batch    0 | Loss (M=1): 1.8160 | LR: 0.021491 | Path noti: 254
# Epoch  49 | Batch   25 | Loss (M=1): 1.8313 | LR: 0.021491 | Path noti: 254
# Epoch  49 | Batch   50 | Loss (M=1): 1.8941 | LR: 0.021491 | Path noti: 254
# Epoch  49 | Batch   75 | Loss (M=1): 1.9059 | LR: 0.021491 | Path noti: 254
# Epoch  49 | Batch  100 | Loss (M=1): 1.8584 | LR: 0.021491 | Path noti: 254
# Epoch  49 | Batch  125 | Loss (M=1): 1.8181 | LR: 0.021491 | Path noti: 254
# Epoch  49 | Batch  150 | Loss (M=1): 1.7226 | LR: 0.021491 | Path noti: 254
# Epoch  49 | Batch  175 | Loss (M=1): 1.9065 | LR: 0.021491 | Path noti: 254
# Epoch  50 | Batch    0 | Loss (M=1): 1.9450 | LR: 0.021353 | Path noti: 254
# Epoch  50 | Batch   25 | Loss (M=1): 1.7290 | LR: 0.021353 | Path noti: 254
# Epoch  50 | Batch   50 | Loss (M=1): 2.3069 | LR: 0.021353 | Path noti: 254
# Epoch  50 | Batch   75 | Loss (M=1): 1.6501 | LR: 0.021353 | Path noti: 254
# Epoch  50 | Batch  100 | Loss (M=1): 1.8307 | LR: 0.021353 | Path noti: 254
# Epoch  50 | Batch  125 | Loss (M=1): 1.8279 | LR: 0.021353 | Path noti: 254
# Epoch  50 | Batch  150 | Loss (M=1): 1.9826 | LR: 0.021353 | Path noti: 254
# Epoch  50 | Batch  175 | Loss (M=1): 1.8604 | LR: 0.021353 | Path noti: 254
# Epoch  51 | Batch    0 | Loss (M=1): 1.9010 | LR: 0.021214 | Path noti: 254
# Epoch  51 | Batch   25 | Loss (M=1): 1.7563 | LR: 0.021214 | Path noti: 254
# Epoch  51 | Batch   50 | Loss (M=1): 1.9188 | LR: 0.021214 | Path noti: 254
# Epoch  51 | Batch   75 | Loss (M=1): 1.7514 | LR: 0.021214 | Path noti: 254
# Epoch  51 | Batch  100 | Loss (M=1): 1.7723 | LR: 0.021214 | Path noti: 254
# Epoch  51 | Batch  125 | Loss (M=1): 2.0351 | LR: 0.021214 | Path noti: 254
# Epoch  51 | Batch  150 | Loss (M=1): 1.8031 | LR: 0.021214 | Path noti: 254
# Epoch  51 | Batch  175 | Loss (M=1): 1.9815 | LR: 0.021214 | Path noti: 254
# Epoch  52 | Batch    0 | Loss (M=1): 1.7436 | LR: 0.021073 | Path noti: 254
# Epoch  52 | Batch   25 | Loss (M=1): 1.7193 | LR: 0.021073 | Path noti: 254
# Epoch  52 | Batch   50 | Loss (M=1): 1.7128 | LR: 0.021073 | Path noti: 254
# Epoch  52 | Batch   75 | Loss (M=1): 2.0077 | LR: 0.021073 | Path noti: 254
# Epoch  52 | Batch  100 | Loss (M=1): 2.0126 | LR: 0.021073 | Path noti: 254
# Epoch  52 | Batch  125 | Loss (M=1): 1.6495 | LR: 0.021073 | Path noti: 254
# Epoch  52 | Batch  150 | Loss (M=1): 1.7783 | LR: 0.021073 | Path noti: 254
# Epoch  52 | Batch  175 | Loss (M=1): 1.7557 | LR: 0.021073 | Path noti: 254
# Epoch  53 | Batch    0 | Loss (M=1): 1.7022 | LR: 0.020929 | Path noti: 254
# Epoch  53 | Batch   25 | Loss (M=1): 2.0243 | LR: 0.020929 | Path noti: 254
# Epoch  53 | Batch   50 | Loss (M=1): 1.6932 | LR: 0.020929 | Path noti: 254
# Epoch  53 | Batch   75 | Loss (M=1): 1.7287 | LR: 0.020929 | Path noti: 254
# Epoch  53 | Batch  100 | Loss (M=1): 1.8168 | LR: 0.020929 | Path noti: 254
# Epoch  53 | Batch  125 | Loss (M=1): 1.7878 | LR: 0.020929 | Path noti: 254
# Epoch  53 | Batch  150 | Loss (M=1): 1.7236 | LR: 0.020929 | Path noti: 254
# Epoch  53 | Batch  175 | Loss (M=1): 1.8488 | LR: 0.020929 | Path noti: 254
# Epoch  54 | Batch    0 | Loss (M=1): 1.7462 | LR: 0.020783 | Path noti: 254
# Epoch  54 | Batch   25 | Loss (M=1): 1.7455 | LR: 0.020783 | Path noti: 254
# Epoch  54 | Batch   50 | Loss (M=1): 1.8069 | LR: 0.020783 | Path noti: 254
# Epoch  54 | Batch   75 | Loss (M=1): 1.7395 | LR: 0.020783 | Path noti: 254
# Epoch  54 | Batch  100 | Loss (M=1): 1.9779 | LR: 0.020783 | Path noti: 254
# Epoch  54 | Batch  125 | Loss (M=1): 1.8884 | LR: 0.020783 | Path noti: 254
# Epoch  54 | Batch  150 | Loss (M=1): 1.8972 | LR: 0.020783 | Path noti: 254
# Epoch  54 | Batch  175 | Loss (M=1): 1.7743 | LR: 0.020783 | Path noti: 254
# Epoch  55 | Batch    0 | Loss (M=1): 1.7202 | LR: 0.020636 | Path noti: 254
# Epoch  55 | Batch   25 | Loss (M=1): 1.8125 | LR: 0.020636 | Path noti: 254
# Epoch  55 | Batch   50 | Loss (M=1): 1.7919 | LR: 0.020636 | Path noti: 254
# Epoch  55 | Batch   75 | Loss (M=1): 1.8402 | LR: 0.020636 | Path noti: 254
# Epoch  55 | Batch  100 | Loss (M=1): 1.9967 | LR: 0.020636 | Path noti: 254
# Epoch  55 | Batch  125 | Loss (M=1): 1.6861 | LR: 0.020636 | Path noti: 254
# Epoch  55 | Batch  150 | Loss (M=1): 1.7526 | LR: 0.020636 | Path noti: 254
# Epoch  55 | Batch  175 | Loss (M=1): 1.7656 | LR: 0.020636 | Path noti: 254
# Epoch  56 | Batch    0 | Loss (M=1): 1.9439 | LR: 0.020486 | Path noti: 254
# Epoch  56 | Batch   25 | Loss (M=1): 1.7791 | LR: 0.020486 | Path noti: 254
# Epoch  56 | Batch   50 | Loss (M=1): 1.8854 | LR: 0.020486 | Path noti: 254
# Epoch  56 | Batch   75 | Loss (M=1): 1.9302 | LR: 0.020486 | Path noti: 254
# Epoch  56 | Batch  100 | Loss (M=1): 1.8104 | LR: 0.020486 | Path noti: 254
# Epoch  56 | Batch  125 | Loss (M=1): 1.8551 | LR: 0.020486 | Path noti: 254
# Epoch  56 | Batch  150 | Loss (M=1): 1.8895 | LR: 0.020486 | Path noti: 254
# Epoch  56 | Batch  175 | Loss (M=1): 2.0102 | LR: 0.020486 | Path noti: 254
# Epoch  57 | Batch    0 | Loss (M=1): 1.9404 | LR: 0.020334 | Path noti: 254
# Epoch  57 | Batch   25 | Loss (M=1): 1.9708 | LR: 0.020334 | Path noti: 254
# Epoch  57 | Batch   50 | Loss (M=1): 1.7801 | LR: 0.020334 | Path noti: 254
# Epoch  57 | Batch   75 | Loss (M=1): 1.8340 | LR: 0.020334 | Path noti: 254
# Epoch  57 | Batch  100 | Loss (M=1): 1.8096 | LR: 0.020334 | Path noti: 254
# Epoch  57 | Batch  125 | Loss (M=1): 1.8089 | LR: 0.020334 | Path noti: 254
# Epoch  57 | Batch  150 | Loss (M=1): 1.7678 | LR: 0.020334 | Path noti: 254
# Epoch  57 | Batch  175 | Loss (M=1): 1.8167 | LR: 0.020334 | Path noti: 254
# Epoch  58 | Batch    0 | Loss (M=1): 1.8267 | LR: 0.020181 | Path noti: 254
# Epoch  58 | Batch   25 | Loss (M=1): 1.6891 | LR: 0.020181 | Path noti: 254
# Epoch  58 | Batch   50 | Loss (M=1): 1.7969 | LR: 0.020181 | Path noti: 254
# Epoch  58 | Batch   75 | Loss (M=1): 1.8073 | LR: 0.020181 | Path noti: 254
# Epoch  58 | Batch  100 | Loss (M=1): 1.8069 | LR: 0.020181 | Path noti: 254
# Epoch  58 | Batch  125 | Loss (M=1): 1.8405 | LR: 0.020181 | Path noti: 254
# Epoch  58 | Batch  150 | Loss (M=1): 1.8578 | LR: 0.020181 | Path noti: 254
# Epoch  58 | Batch  175 | Loss (M=1): 1.8887 | LR: 0.020181 | Path noti: 254
# Epoch  59 | Batch    0 | Loss (M=1): 1.6710 | LR: 0.020025 | Path noti: 254
# Epoch  59 | Batch   25 | Loss (M=1): 1.8168 | LR: 0.020025 | Path noti: 254
# Epoch  59 | Batch   50 | Loss (M=1): 2.0356 | LR: 0.020025 | Path noti: 254
# Epoch  59 | Batch   75 | Loss (M=1): 1.7493 | LR: 0.020025 | Path noti: 254
# Epoch  59 | Batch  100 | Loss (M=1): 1.8667 | LR: 0.020025 | Path noti: 254
# Epoch  59 | Batch  125 | Loss (M=1): 1.8941 | LR: 0.020025 | Path noti: 254
# Epoch  59 | Batch  150 | Loss (M=1): 2.0243 | LR: 0.020025 | Path noti: 254
# Epoch  59 | Batch  175 | Loss (M=1): 1.7161 | LR: 0.020025 | Path noti: 254
# Epoch  60 | Batch    0 | Loss (M=1): 1.6298 | LR: 0.019868 | Path noti: 254
# Epoch  60 | Batch   25 | Loss (M=1): 1.8074 | LR: 0.019868 | Path noti: 254
# Epoch  60 | Batch   50 | Loss (M=1): 1.7543 | LR: 0.019868 | Path noti: 254
# Epoch  60 | Batch   75 | Loss (M=1): 2.0432 | LR: 0.019868 | Path noti: 254
# Epoch  60 | Batch  100 | Loss (M=1): 1.8441 | LR: 0.019868 | Path noti: 254
# Epoch  60 | Batch  125 | Loss (M=1): 1.6725 | LR: 0.019868 | Path noti: 254
# Epoch  60 | Batch  150 | Loss (M=1): 1.9975 | LR: 0.019868 | Path noti: 254
# Epoch  60 | Batch  175 | Loss (M=1): 1.8425 | LR: 0.019868 | Path noti: 254
# Epoch  61 | Batch    0 | Loss (M=1): 1.8834 | LR: 0.019709 | Path noti: 254
# Epoch  61 | Batch   25 | Loss (M=1): 1.8500 | LR: 0.019709 | Path noti: 254
# Epoch  61 | Batch   50 | Loss (M=1): 1.7161 | LR: 0.019709 | Path noti: 254
# Epoch  61 | Batch   75 | Loss (M=1): 1.8650 | LR: 0.019709 | Path noti: 254
# Epoch  61 | Batch  100 | Loss (M=1): 2.0221 | LR: 0.019709 | Path noti: 254
# Epoch  61 | Batch  125 | Loss (M=1): 1.9249 | LR: 0.019709 | Path noti: 254
# Epoch  61 | Batch  150 | Loss (M=1): 1.8572 | LR: 0.019709 | Path noti: 254
# Epoch  61 | Batch  175 | Loss (M=1): 1.6863 | LR: 0.019709 | Path noti: 254
# Epoch  62 | Batch    0 | Loss (M=1): 1.7136 | LR: 0.019548 | Path noti: 254
# Epoch  62 | Batch   25 | Loss (M=1): 1.6491 | LR: 0.019548 | Path noti: 254
# Epoch  62 | Batch   50 | Loss (M=1): 1.8976 | LR: 0.019548 | Path noti: 254
# Epoch  62 | Batch   75 | Loss (M=1): 1.7806 | LR: 0.019548 | Path noti: 254
# Epoch  62 | Batch  100 | Loss (M=1): 1.8538 | LR: 0.019548 | Path noti: 254
# Epoch  62 | Batch  125 | Loss (M=1): 1.6775 | LR: 0.019548 | Path noti: 254
# Epoch  62 | Batch  150 | Loss (M=1): 1.7921 | LR: 0.019548 | Path noti: 254
# Epoch  62 | Batch  175 | Loss (M=1): 1.8147 | LR: 0.019548 | Path noti: 254
# Epoch  63 | Batch    0 | Loss (M=1): 2.0190 | LR: 0.019385 | Path noti: 254
# Epoch  63 | Batch   25 | Loss (M=1): 1.7068 | LR: 0.019385 | Path noti: 254
# Epoch  63 | Batch   50 | Loss (M=1): 1.7615 | LR: 0.019385 | Path noti: 254
# Epoch  63 | Batch   75 | Loss (M=1): 1.8159 | LR: 0.019385 | Path noti: 254
# Epoch  63 | Batch  100 | Loss (M=1): 1.6967 | LR: 0.019385 | Path noti: 254
# Epoch  63 | Batch  125 | Loss (M=1): 1.7948 | LR: 0.019385 | Path noti: 254
# Epoch  63 | Batch  150 | Loss (M=1): 1.8291 | LR: 0.019385 | Path noti: 254
# Epoch  63 | Batch  175 | Loss (M=1): 1.7281 | LR: 0.019385 | Path noti: 254
# Epoch  64 | Batch    0 | Loss (M=1): 1.8327 | LR: 0.019221 | Path noti: 254
# Epoch  64 | Batch   25 | Loss (M=1): 1.8903 | LR: 0.019221 | Path noti: 254
# Epoch  64 | Batch   50 | Loss (M=1): 1.7809 | LR: 0.019221 | Path noti: 254
# Epoch  64 | Batch   75 | Loss (M=1): 1.8681 | LR: 0.019221 | Path noti: 254
# Epoch  64 | Batch  100 | Loss (M=1): 1.7781 | LR: 0.019221 | Path noti: 254
# Epoch  64 | Batch  125 | Loss (M=1): 1.8205 | LR: 0.019221 | Path noti: 254
# Epoch  64 | Batch  150 | Loss (M=1): 1.8482 | LR: 0.019221 | Path noti: 254
# Epoch  64 | Batch  175 | Loss (M=1): 1.7952 | LR: 0.019221 | Path noti: 254
# Epoch  65 | Batch    0 | Loss (M=1): 1.6715 | LR: 0.019055 | Path noti: 254
# Epoch  65 | Batch   25 | Loss (M=1): 1.7174 | LR: 0.019055 | Path noti: 254
# Epoch  65 | Batch   50 | Loss (M=1): 1.8192 | LR: 0.019055 | Path noti: 254
# Epoch  65 | Batch   75 | Loss (M=1): 1.6982 | LR: 0.019055 | Path noti: 254
# Epoch  65 | Batch  100 | Loss (M=1): 1.7687 | LR: 0.019055 | Path noti: 254
# Epoch  65 | Batch  125 | Loss (M=1): 1.7847 | LR: 0.019055 | Path noti: 254
# Epoch  65 | Batch  150 | Loss (M=1): 1.8988 | LR: 0.019055 | Path noti: 254
# Epoch  65 | Batch  175 | Loss (M=1): 1.7266 | LR: 0.019055 | Path noti: 254
# Epoch  66 | Batch    0 | Loss (M=1): 1.7313 | LR: 0.018888 | Path noti: 254
# Epoch  66 | Batch   25 | Loss (M=1): 1.8708 | LR: 0.018888 | Path noti: 254
# Epoch  66 | Batch   50 | Loss (M=1): 1.7691 | LR: 0.018888 | Path noti: 254
# Epoch  66 | Batch   75 | Loss (M=1): 1.8821 | LR: 0.018888 | Path noti: 254
# Epoch  66 | Batch  100 | Loss (M=1): 1.8619 | LR: 0.018888 | Path noti: 254
# Epoch  66 | Batch  125 | Loss (M=1): 1.6181 | LR: 0.018888 | Path noti: 254
# Epoch  66 | Batch  150 | Loss (M=1): 1.6227 | LR: 0.018888 | Path noti: 254
# Epoch  66 | Batch  175 | Loss (M=1): 1.8041 | LR: 0.018888 | Path noti: 254
# Epoch  67 | Batch    0 | Loss (M=1): 1.7690 | LR: 0.018718 | Path noti: 254
# Epoch  67 | Batch   25 | Loss (M=1): 2.0131 | LR: 0.018718 | Path noti: 254
# Epoch  67 | Batch   50 | Loss (M=1): 1.6274 | LR: 0.018718 | Path noti: 254
# Epoch  67 | Batch   75 | Loss (M=1): 2.0038 | LR: 0.018718 | Path noti: 254
# Epoch  67 | Batch  100 | Loss (M=1): 1.7228 | LR: 0.018718 | Path noti: 254
# Epoch  67 | Batch  125 | Loss (M=1): 1.7892 | LR: 0.018718 | Path noti: 254
# Epoch  67 | Batch  150 | Loss (M=1): 2.0275 | LR: 0.018718 | Path noti: 254
# Epoch  67 | Batch  175 | Loss (M=1): 2.0209 | LR: 0.018718 | Path noti: 254
# Epoch  68 | Batch    0 | Loss (M=1): 1.7420 | LR: 0.018548 | Path noti: 254
# Epoch  68 | Batch   25 | Loss (M=1): 1.6776 | LR: 0.018548 | Path noti: 254
# Epoch  68 | Batch   50 | Loss (M=1): 1.6705 | LR: 0.018548 | Path noti: 254
# Epoch  68 | Batch   75 | Loss (M=1): 1.6628 | LR: 0.018548 | Path noti: 254
# Epoch  68 | Batch  100 | Loss (M=1): 1.8836 | LR: 0.018548 | Path noti: 254
# Epoch  68 | Batch  125 | Loss (M=1): 1.8186 | LR: 0.018548 | Path noti: 254
# Epoch  68 | Batch  150 | Loss (M=1): 1.6540 | LR: 0.018548 | Path noti: 254
# Epoch  68 | Batch  175 | Loss (M=1): 2.0365 | LR: 0.018548 | Path noti: 254
# Epoch  69 | Batch    0 | Loss (M=1): 1.8560 | LR: 0.018376 | Path noti: 254
# Epoch  69 | Batch   25 | Loss (M=1): 1.7358 | LR: 0.018376 | Path noti: 254
# Epoch  69 | Batch   50 | Loss (M=1): 1.8237 | LR: 0.018376 | Path noti: 254
# Epoch  69 | Batch   75 | Loss (M=1): 1.9950 | LR: 0.018376 | Path noti: 254
# Epoch  69 | Batch  100 | Loss (M=1): 1.8468 | LR: 0.018376 | Path noti: 254
# Epoch  69 | Batch  125 | Loss (M=1): 1.8201 | LR: 0.018376 | Path noti: 254
# Epoch  69 | Batch  150 | Loss (M=1): 1.8254 | LR: 0.018376 | Path noti: 254
# Epoch  69 | Batch  175 | Loss (M=1): 1.6353 | LR: 0.018376 | Path noti: 254
# Epoch  70 | Batch    0 | Loss (M=1): 1.8189 | LR: 0.018202 | Path noti: 254
# Epoch  70 | Batch   25 | Loss (M=1): 2.0197 | LR: 0.018202 | Path noti: 254
# Epoch  70 | Batch   50 | Loss (M=1): 1.6606 | LR: 0.018202 | Path noti: 254
# Epoch  70 | Batch   75 | Loss (M=1): 1.6517 | LR: 0.018202 | Path noti: 254
# Epoch  70 | Batch  100 | Loss (M=1): 1.7214 | LR: 0.018202 | Path noti: 254
# Epoch  70 | Batch  125 | Loss (M=1): 1.7333 | LR: 0.018202 | Path noti: 254
# Epoch  70 | Batch  150 | Loss (M=1): 1.6284 | LR: 0.018202 | Path noti: 254
# Epoch  70 | Batch  175 | Loss (M=1): 1.8540 | LR: 0.018202 | Path noti: 254
# Epoch  71 | Batch    0 | Loss (M=1): 1.9000 | LR: 0.018027 | Path noti: 254
# Epoch  71 | Batch   25 | Loss (M=1): 1.7135 | LR: 0.018027 | Path noti: 254
# Epoch  71 | Batch   50 | Loss (M=1): 1.6433 | LR: 0.018027 | Path noti: 254
# Epoch  71 | Batch   75 | Loss (M=1): 1.6825 | LR: 0.018027 | Path noti: 254
# Epoch  71 | Batch  100 | Loss (M=1): 1.8402 | LR: 0.018027 | Path noti: 254
# Epoch  71 | Batch  125 | Loss (M=1): 1.8789 | LR: 0.018027 | Path noti: 254
# Epoch  71 | Batch  150 | Loss (M=1): 1.8996 | LR: 0.018027 | Path noti: 254
# Epoch  71 | Batch  175 | Loss (M=1): 2.0073 | LR: 0.018027 | Path noti: 254
# Epoch  72 | Batch    0 | Loss (M=1): 1.9091 | LR: 0.017851 | Path noti: 254
# Epoch  72 | Batch   25 | Loss (M=1): 1.7709 | LR: 0.017851 | Path noti: 254
# Epoch  72 | Batch   50 | Loss (M=1): 1.8253 | LR: 0.017851 | Path noti: 254
# Epoch  72 | Batch   75 | Loss (M=1): 1.7971 | LR: 0.017851 | Path noti: 254
# Epoch  72 | Batch  100 | Loss (M=1): 1.8129 | LR: 0.017851 | Path noti: 254
# Epoch  72 | Batch  125 | Loss (M=1): 2.0187 | LR: 0.017851 | Path noti: 254
# Epoch  72 | Batch  150 | Loss (M=1): 1.7959 | LR: 0.017851 | Path noti: 254
# Epoch  72 | Batch  175 | Loss (M=1): 1.6791 | LR: 0.017851 | Path noti: 254
# Epoch  73 | Batch    0 | Loss (M=1): 1.6087 | LR: 0.017673 | Path noti: 254
# Epoch  73 | Batch   25 | Loss (M=1): 1.8498 | LR: 0.017673 | Path noti: 254
# Epoch  73 | Batch   50 | Loss (M=1): 1.6470 | LR: 0.017673 | Path noti: 254
# Epoch  73 | Batch   75 | Loss (M=1): 1.6794 | LR: 0.017673 | Path noti: 254
# Epoch  73 | Batch  100 | Loss (M=1): 1.9399 | LR: 0.017673 | Path noti: 254
# Epoch  73 | Batch  125 | Loss (M=1): 1.8073 | LR: 0.017673 | Path noti: 254
# Epoch  73 | Batch  150 | Loss (M=1): 1.8106 | LR: 0.017673 | Path noti: 254
# Epoch  73 | Batch  175 | Loss (M=1): 1.8355 | LR: 0.017673 | Path noti: 254
# Epoch  74 | Batch    0 | Loss (M=1): 1.6168 | LR: 0.017494 | Path noti: 254
# Epoch  74 | Batch   25 | Loss (M=1): 1.7556 | LR: 0.017494 | Path noti: 254
# Epoch  74 | Batch   50 | Loss (M=1): 1.5966 | LR: 0.017494 | Path noti: 254
# Epoch  74 | Batch   75 | Loss (M=1): 1.7202 | LR: 0.017494 | Path noti: 254
# Epoch  74 | Batch  100 | Loss (M=1): 1.6440 | LR: 0.017494 | Path noti: 254
# Epoch  74 | Batch  125 | Loss (M=1): 1.7449 | LR: 0.017494 | Path noti: 254
# Epoch  74 | Batch  150 | Loss (M=1): 1.5969 | LR: 0.017494 | Path noti: 254
# Epoch  74 | Batch  175 | Loss (M=1): 1.6316 | LR: 0.017494 | Path noti: 254
# Epoch  75 | Batch    0 | Loss (M=1): 1.7548 | LR: 0.017314 | Path noti: 254
# Epoch  75 | Batch   25 | Loss (M=1): 1.7569 | LR: 0.017314 | Path noti: 254
# Epoch  75 | Batch   50 | Loss (M=1): 1.8386 | LR: 0.017314 | Path noti: 254
# Epoch  75 | Batch   75 | Loss (M=1): 1.6806 | LR: 0.017314 | Path noti: 254
# Epoch  75 | Batch  100 | Loss (M=1): 1.6437 | LR: 0.017314 | Path noti: 254
# Epoch  75 | Batch  125 | Loss (M=1): 1.7299 | LR: 0.017314 | Path noti: 254
# Epoch  75 | Batch  150 | Loss (M=1): 1.7748 | LR: 0.017314 | Path noti: 254
# Epoch  75 | Batch  175 | Loss (M=1): 1.7405 | LR: 0.017314 | Path noti: 254
# Epoch  76 | Batch    0 | Loss (M=1): 1.6478 | LR: 0.017133 | Path noti: 254
# Epoch  76 | Batch   25 | Loss (M=1): 1.7487 | LR: 0.017133 | Path noti: 254
# Epoch  76 | Batch   50 | Loss (M=1): 1.7180 | LR: 0.017133 | Path noti: 254
# Epoch  76 | Batch   75 | Loss (M=1): 1.8331 | LR: 0.017133 | Path noti: 254
# Epoch  76 | Batch  100 | Loss (M=1): 1.7226 | LR: 0.017133 | Path noti: 254
# Epoch  76 | Batch  125 | Loss (M=1): 2.0053 | LR: 0.017133 | Path noti: 254
# Epoch  76 | Batch  150 | Loss (M=1): 1.7944 | LR: 0.017133 | Path noti: 254
# Epoch  76 | Batch  175 | Loss (M=1): 1.8049 | LR: 0.017133 | Path noti: 254
# Epoch  77 | Batch    0 | Loss (M=1): 1.8147 | LR: 0.016951 | Path noti: 254
# Epoch  77 | Batch   25 | Loss (M=1): 1.7023 | LR: 0.016951 | Path noti: 254
# Epoch  77 | Batch   50 | Loss (M=1): 1.7945 | LR: 0.016951 | Path noti: 254
# Epoch  77 | Batch   75 | Loss (M=1): 1.6658 | LR: 0.016951 | Path noti: 254
# Epoch  77 | Batch  100 | Loss (M=1): 1.7737 | LR: 0.016951 | Path noti: 254
# Epoch  77 | Batch  125 | Loss (M=1): 1.8238 | LR: 0.016951 | Path noti: 254
# Epoch  77 | Batch  150 | Loss (M=1): 1.6979 | LR: 0.016951 | Path noti: 254
# Epoch  77 | Batch  175 | Loss (M=1): 1.8542 | LR: 0.016951 | Path noti: 254
# Epoch  78 | Batch    0 | Loss (M=1): 1.7059 | LR: 0.016767 | Path noti: 254
# Epoch  78 | Batch   25 | Loss (M=1): 1.7286 | LR: 0.016767 | Path noti: 254
# Epoch  78 | Batch   50 | Loss (M=1): 1.8206 | LR: 0.016767 | Path noti: 254
# Epoch  78 | Batch   75 | Loss (M=1): 1.8383 | LR: 0.016767 | Path noti: 254
# Epoch  78 | Batch  100 | Loss (M=1): 1.7839 | LR: 0.016767 | Path noti: 254
# Epoch  78 | Batch  125 | Loss (M=1): 1.7478 | LR: 0.016767 | Path noti: 254
# Epoch  78 | Batch  150 | Loss (M=1): 1.6683 | LR: 0.016767 | Path noti: 254
# ...
# Epoch  98 | Batch   75 | Loss (M=1): 1.7643 | LR: 0.012941 | Path noti: 254
# Epoch  98 | Batch  100 | Loss (M=1): 1.8315 | LR: 0.012941 | Path noti: 254
# Epoch  98 | Batch  125 | Loss (M=1): 1.8237 | LR: 0.012941 | Path noti: 254
# Epoch  98 | Batch  150 | Loss (M=1): 1.7878 | LR: 0.012941 | Path noti: 254
# Epoch  98 | Batch  175 | Loss (M=1): 1.7090 | LR: 0.012941 | Path noti: 254
# Epoch  99 | Batch    0 | Loss (M=1): 1.6516 | LR: 0.012746 | Path noti: 254
# Epoch  99 | Batch   25 | Loss (M=1): 1.8073 | LR: 0.012746 | Path noti: 254
# Epoch  99 | Batch   50 | Loss (M=1): 1.6574 | LR: 0.012746 | Path noti: 254
# Epoch  99 | Batch   75 | Loss (M=1): 1.7361 | LR: 0.012746 | Path noti: 254
# Epoch  99 | Batch  100 | Loss (M=1): 1.6504 | LR: 0.012746 | Path noti: 254
# Epoch  99 | Batch  125 | Loss (M=1): 1.7737 | LR: 0.012746 | Path noti: 254
# Epoch  99 | Batch  150 | Loss (M=1): 1.7135 | LR: 0.012746 | Path noti: 254
# Epoch  99 | Batch  175 | Loss (M=1): 1.6092 | LR: 0.012746 | Path noti: 254
# Epoch 100 | Batch    0 | Loss (M=1): 1.9338 | LR: 0.012550 | Path noti: 254
# Epoch 100 | Batch   25 | Loss (M=1): 1.6728 | LR: 0.012550 | Path noti: 254
# Epoch 100 | Batch   50 | Loss (M=1): 1.9106 | LR: 0.012550 | Path noti: 254
# Epoch 100 | Batch   75 | Loss (M=1): 1.7827 | LR: 0.012550 | Path noti: 254
# Epoch 100 | Batch  100 | Loss (M=1): 1.9883 | LR: 0.012550 | Path noti: 254
# Epoch 100 | Batch  125 | Loss (M=1): 1.8028 | LR: 0.012550 | Path noti: 254
# Epoch 100 | Batch  150 | Loss (M=1): 1.5904 | LR: 0.012550 | Path noti: 254
# Epoch 100 | Batch  175 | Loss (M=1): 1.6419 | LR: 0.012550 | Path noti: 254
# Epoch 101 | Batch    0 | Loss (M=1): 1.7737 | LR: 0.012354 | Path noti: 254
# Epoch 101 | Batch   25 | Loss (M=1): 1.6869 | LR: 0.012354 | Path noti: 254
# Epoch 101 | Batch   50 | Loss (M=1): 1.8274 | LR: 0.012354 | Path noti: 254
# Epoch 101 | Batch   75 | Loss (M=1): 1.6081 | LR: 0.012354 | Path noti: 254
# Epoch 101 | Batch  100 | Loss (M=1): 1.8113 | LR: 0.012354 | Path noti: 254
# Epoch 101 | Batch  125 | Loss (M=1): 1.9877 | LR: 0.012354 | Path noti: 254
# Epoch 101 | Batch  150 | Loss (M=1): 1.6768 | LR: 0.012354 | Path noti: 254
# Epoch 101 | Batch  175 | Loss (M=1): 1.7807 | LR: 0.012354 | Path noti: 254
# Epoch 102 | Batch    0 | Loss (M=1): 1.6851 | LR: 0.012159 | Path noti: 254
# Epoch 102 | Batch   25 | Loss (M=1): 1.6250 | LR: 0.012159 | Path noti: 254
# Epoch 102 | Batch   50 | Loss (M=1): 1.7835 | LR: 0.012159 | Path noti: 254
# Epoch 102 | Batch   75 | Loss (M=1): 1.6694 | LR: 0.012159 | Path noti: 254
# Epoch 102 | Batch  100 | Loss (M=1): 1.6681 | LR: 0.012159 | Path noti: 254
# Epoch 102 | Batch  125 | Loss (M=1): 1.9563 | LR: 0.012159 | Path noti: 254
# Epoch 102 | Batch  150 | Loss (M=1): 1.6341 | LR: 0.012159 | Path noti: 254
# Epoch 102 | Batch  175 | Loss (M=1): 2.3052 | LR: 0.012159 | Path noti: 254
# Epoch 103 | Batch    0 | Loss (M=1): 1.7010 | LR: 0.011964 | Path noti: 254
# Epoch 103 | Batch   25 | Loss (M=1): 1.9328 | LR: 0.011964 | Path noti: 254
# Epoch 103 | Batch   50 | Loss (M=1): 1.8503 | LR: 0.011964 | Path noti: 254
# Epoch 103 | Batch   75 | Loss (M=1): 1.8151 | LR: 0.011964 | Path noti: 254
# Epoch 103 | Batch  100 | Loss (M=1): 1.5457 | LR: 0.011964 | Path noti: 254
# Epoch 103 | Batch  125 | Loss (M=1): 1.9059 | LR: 0.011964 | Path noti: 254
# Epoch 103 | Batch  150 | Loss (M=1): 1.6589 | LR: 0.011964 | Path noti: 254
# Epoch 103 | Batch  175 | Loss (M=1): 1.9848 | LR: 0.011964 | Path noti: 254
# Epoch 104 | Batch    0 | Loss (M=1): 1.9979 | LR: 0.011768 | Path noti: 254
# Epoch 104 | Batch   25 | Loss (M=1): 1.7965 | LR: 0.011768 | Path noti: 254
# Epoch 104 | Batch   50 | Loss (M=1): 1.7154 | LR: 0.011768 | Path noti: 254
# Epoch 104 | Batch   75 | Loss (M=1): 1.6948 | LR: 0.011768 | Path noti: 254
# Epoch 104 | Batch  100 | Loss (M=1): 1.7620 | LR: 0.011768 | Path noti: 254
# Epoch 104 | Batch  125 | Loss (M=1): 1.7000 | LR: 0.011768 | Path noti: 254
# Epoch 104 | Batch  150 | Loss (M=1): 1.8221 | LR: 0.011768 | Path noti: 254
# Epoch 104 | Batch  175 | Loss (M=1): 1.7930 | LR: 0.011768 | Path noti: 254
# Epoch 105 | Batch    0 | Loss (M=1): 1.5835 | LR: 0.011573 | Path noti: 254
# Epoch 105 | Batch   25 | Loss (M=1): 1.7435 | LR: 0.011573 | Path noti: 254
# Epoch 105 | Batch   50 | Loss (M=1): 1.9667 | LR: 0.011573 | Path noti: 254
# Epoch 105 | Batch   75 | Loss (M=1): 1.7015 | LR: 0.011573 | Path noti: 254
# Epoch 105 | Batch  100 | Loss (M=1): 1.6023 | LR: 0.011573 | Path noti: 254
# Epoch 105 | Batch  125 | Loss (M=1): 1.7110 | LR: 0.011573 | Path noti: 254
# Epoch 105 | Batch  150 | Loss (M=1): 1.9659 | LR: 0.011573 | Path noti: 254
# Epoch 105 | Batch  175 | Loss (M=1): 1.5900 | LR: 0.011573 | Path noti: 254
# Epoch 106 | Batch    0 | Loss (M=1): 2.0108 | LR: 0.011378 | Path noti: 254
# Epoch 106 | Batch   25 | Loss (M=1): 1.8042 | LR: 0.011378 | Path noti: 254
# Epoch 106 | Batch   50 | Loss (M=1): 1.9934 | LR: 0.011378 | Path noti: 254
# Epoch 106 | Batch   75 | Loss (M=1): 1.9856 | LR: 0.011378 | Path noti: 254
# Epoch 106 | Batch  100 | Loss (M=1): 1.6738 | LR: 0.011378 | Path noti: 254
# Epoch 106 | Batch  125 | Loss (M=1): 1.6012 | LR: 0.011378 | Path noti: 254
# Epoch 106 | Batch  150 | Loss (M=1): 1.8007 | LR: 0.011378 | Path noti: 254
# Epoch 106 | Batch  175 | Loss (M=1): 1.7015 | LR: 0.011378 | Path noti: 254
# Epoch 107 | Batch    0 | Loss (M=1): 1.7538 | LR: 0.011184 | Path noti: 254
# Epoch 107 | Batch   25 | Loss (M=1): 1.8413 | LR: 0.011184 | Path noti: 254
# Epoch 107 | Batch   50 | Loss (M=1): 1.5828 | LR: 0.011184 | Path noti: 254
# Epoch 107 | Batch   75 | Loss (M=1): 1.6790 | LR: 0.011184 | Path noti: 254
# Epoch 107 | Batch  100 | Loss (M=1): 1.9008 | LR: 0.011184 | Path noti: 254
# Epoch 107 | Batch  125 | Loss (M=1): 1.7293 | LR: 0.011184 | Path noti: 254
# Epoch 107 | Batch  150 | Loss (M=1): 1.9122 | LR: 0.011184 | Path noti: 254
# Epoch 107 | Batch  175 | Loss (M=1): 1.6151 | LR: 0.011184 | Path noti: 254
# Epoch 108 | Batch    0 | Loss (M=1): 1.8866 | LR: 0.010990 | Path noti: 254
# Epoch 108 | Batch   25 | Loss (M=1): 1.7846 | LR: 0.010990 | Path noti: 254
# Epoch 108 | Batch   50 | Loss (M=1): 2.0188 | LR: 0.010990 | Path noti: 254
# Epoch 108 | Batch   75 | Loss (M=1): 1.7911 | LR: 0.010990 | Path noti: 254
# Epoch 108 | Batch  100 | Loss (M=1): 1.7209 | LR: 0.010990 | Path noti: 254
# Epoch 108 | Batch  125 | Loss (M=1): 1.7911 | LR: 0.010990 | Path noti: 254
# Epoch 108 | Batch  150 | Loss (M=1): 1.6386 | LR: 0.010990 | Path noti: 254
# Epoch 108 | Batch  175 | Loss (M=1): 1.7635 | LR: 0.010990 | Path noti: 254
# Epoch 109 | Batch    0 | Loss (M=1): 1.7117 | LR: 0.010796 | Path noti: 254
# Epoch 109 | Batch   25 | Loss (M=1): 1.6816 | LR: 0.010796 | Path noti: 254
# Epoch 109 | Batch   50 | Loss (M=1): 1.8157 | LR: 0.010796 | Path noti: 254
# Epoch 109 | Batch   75 | Loss (M=1): 1.8747 | LR: 0.010796 | Path noti: 254
# Epoch 109 | Batch  100 | Loss (M=1): 1.9988 | LR: 0.010796 | Path noti: 254
# Epoch 109 | Batch  125 | Loss (M=1): 2.0390 | LR: 0.010796 | Path noti: 254
# Epoch 109 | Batch  150 | Loss (M=1): 1.9961 | LR: 0.010796 | Path noti: 254
# Epoch 109 | Batch  175 | Loss (M=1): 1.8372 | LR: 0.010796 | Path noti: 254
# Epoch 110 | Batch    0 | Loss (M=1): 1.7154 | LR: 0.010602 | Path noti: 254
# Epoch 110 | Batch   25 | Loss (M=1): 1.8139 | LR: 0.010602 | Path noti: 254
# Epoch 110 | Batch   50 | Loss (M=1): 1.5843 | LR: 0.010602 | Path noti: 254
# Epoch 110 | Batch   75 | Loss (M=1): 1.9805 | LR: 0.010602 | Path noti: 254
# Epoch 110 | Batch  100 | Loss (M=1): 1.7587 | LR: 0.010602 | Path noti: 254
# Epoch 110 | Batch  125 | Loss (M=1): 1.5970 | LR: 0.010602 | Path noti: 254
# Epoch 110 | Batch  150 | Loss (M=1): 1.7158 | LR: 0.010602 | Path noti: 254
# Epoch 110 | Batch  175 | Loss (M=1): 1.6384 | LR: 0.010602 | Path noti: 254
# Epoch 111 | Batch    0 | Loss (M=1): 2.3046 | LR: 0.010409 | Path noti: 254
# Epoch 111 | Batch   25 | Loss (M=1): 1.6767 | LR: 0.010409 | Path noti: 254
# Epoch 111 | Batch   50 | Loss (M=1): 2.0002 | LR: 0.010409 | Path noti: 254
# Epoch 111 | Batch   75 | Loss (M=1): 1.7821 | LR: 0.010409 | Path noti: 254
# Epoch 111 | Batch  100 | Loss (M=1): 1.7019 | LR: 0.010409 | Path noti: 254
# Epoch 111 | Batch  125 | Loss (M=1): 1.7892 | LR: 0.010409 | Path noti: 254
# Epoch 111 | Batch  150 | Loss (M=1): 1.5572 | LR: 0.010409 | Path noti: 254
# Epoch 111 | Batch  175 | Loss (M=1): 1.7867 | LR: 0.010409 | Path noti: 254
# Epoch 112 | Batch    0 | Loss (M=1): 1.6450 | LR: 0.010217 | Path noti: 254
# Epoch 112 | Batch   25 | Loss (M=1): 1.8234 | LR: 0.010217 | Path noti: 254
# Epoch 112 | Batch   50 | Loss (M=1): 1.6946 | LR: 0.010217 | Path noti: 254
# Epoch 112 | Batch   75 | Loss (M=1): 1.6329 | LR: 0.010217 | Path noti: 254
# Epoch 112 | Batch  100 | Loss (M=1): 1.6115 | LR: 0.010217 | Path noti: 254
# Epoch 112 | Batch  125 | Loss (M=1): 1.6062 | LR: 0.010217 | Path noti: 254
# Epoch 112 | Batch  150 | Loss (M=1): 1.6920 | LR: 0.010217 | Path noti: 254
# Epoch 112 | Batch  175 | Loss (M=1): 1.8188 | LR: 0.010217 | Path noti: 254
# Epoch 113 | Batch    0 | Loss (M=1): 1.5995 | LR: 0.010025 | Path noti: 254
# Epoch 113 | Batch   25 | Loss (M=1): 1.5762 | LR: 0.010025 | Path noti: 254
# Epoch 113 | Batch   50 | Loss (M=1): 1.6994 | LR: 0.010025 | Path noti: 254
# Epoch 113 | Batch   75 | Loss (M=1): 1.7321 | LR: 0.010025 | Path noti: 254
# Epoch 113 | Batch  100 | Loss (M=1): 1.8401 | LR: 0.010025 | Path noti: 254
# Epoch 113 | Batch  125 | Loss (M=1): 1.7059 | LR: 0.010025 | Path noti: 254
# Epoch 113 | Batch  150 | Loss (M=1): 1.9705 | LR: 0.010025 | Path noti: 254
# Epoch 113 | Batch  175 | Loss (M=1): 1.7648 | LR: 0.010025 | Path noti: 254
# Epoch 114 | Batch    0 | Loss (M=1): 1.7803 | LR: 0.009834 | Path noti: 254
# Epoch 114 | Batch   25 | Loss (M=1): 1.7279 | LR: 0.009834 | Path noti: 254
# Epoch 114 | Batch   50 | Loss (M=1): 1.7555 | LR: 0.009834 | Path noti: 254
# Epoch 114 | Batch   75 | Loss (M=1): 1.6906 | LR: 0.009834 | Path noti: 254
# Epoch 114 | Batch  100 | Loss (M=1): 1.9079 | LR: 0.009834 | Path noti: 254
# Epoch 114 | Batch  125 | Loss (M=1): 1.9035 | LR: 0.009834 | Path noti: 254
# Epoch 114 | Batch  150 | Loss (M=1): 2.0004 | LR: 0.009834 | Path noti: 254
# Epoch 114 | Batch  175 | Loss (M=1): 1.6092 | LR: 0.009834 | Path noti: 254
# Epoch 115 | Batch    0 | Loss (M=1): 1.6267 | LR: 0.009644 | Path noti: 254
# Epoch 115 | Batch   25 | Loss (M=1): 1.6653 | LR: 0.009644 | Path noti: 254
# Epoch 115 | Batch   50 | Loss (M=1): 1.6672 | LR: 0.009644 | Path noti: 254
# Epoch 115 | Batch   75 | Loss (M=1): 1.7253 | LR: 0.009644 | Path noti: 254
# Epoch 115 | Batch  100 | Loss (M=1): 1.8251 | LR: 0.009644 | Path noti: 254
# Epoch 115 | Batch  125 | Loss (M=1): 1.6859 | LR: 0.009644 | Path noti: 254
# Epoch 115 | Batch  150 | Loss (M=1): 1.7061 | LR: 0.009644 | Path noti: 254
# Epoch 115 | Batch  175 | Loss (M=1): 1.7517 | LR: 0.009644 | Path noti: 254
# Epoch 116 | Batch    0 | Loss (M=1): 1.6966 | LR: 0.009454 | Path noti: 254
# Epoch 116 | Batch   25 | Loss (M=1): 1.6000 | LR: 0.009454 | Path noti: 254
# Epoch 116 | Batch   50 | Loss (M=1): 1.6324 | LR: 0.009454 | Path noti: 254
# Epoch 116 | Batch   75 | Loss (M=1): 1.5886 | LR: 0.009454 | Path noti: 254
# Epoch 116 | Batch  100 | Loss (M=1): 1.7391 | LR: 0.009454 | Path noti: 254
# Epoch 116 | Batch  125 | Loss (M=1): 1.5875 | LR: 0.009454 | Path noti: 254
# Epoch 116 | Batch  150 | Loss (M=1): 1.7944 | LR: 0.009454 | Path noti: 254
# Epoch 116 | Batch  175 | Loss (M=1): 1.7971 | LR: 0.009454 | Path noti: 254
# Epoch 117 | Batch    0 | Loss (M=1): 1.7770 | LR: 0.009265 | Path noti: 254
# Epoch 117 | Batch   25 | Loss (M=1): 1.6827 | LR: 0.009265 | Path noti: 254
# Epoch 117 | Batch   50 | Loss (M=1): 1.6614 | LR: 0.009265 | Path noti: 254
# Epoch 117 | Batch   75 | Loss (M=1): 1.6636 | LR: 0.009265 | Path noti: 254
# Epoch 117 | Batch  100 | Loss (M=1): 1.7950 | LR: 0.009265 | Path noti: 254
# Epoch 117 | Batch  125 | Loss (M=1): 1.7366 | LR: 0.009265 | Path noti: 254
# Epoch 117 | Batch  150 | Loss (M=1): 1.5945 | LR: 0.009265 | Path noti: 254
# Epoch 117 | Batch  175 | Loss (M=1): 1.7147 | LR: 0.009265 | Path noti: 254
# Epoch 118 | Batch    0 | Loss (M=1): 1.6014 | LR: 0.009077 | Path noti: 254
# Epoch 118 | Batch   25 | Loss (M=1): 1.6712 | LR: 0.009077 | Path noti: 254
# Epoch 118 | Batch   50 | Loss (M=1): 1.8119 | LR: 0.009077 | Path noti: 254
# Epoch 118 | Batch   75 | Loss (M=1): 1.7634 | LR: 0.009077 | Path noti: 254
# Epoch 118 | Batch  100 | Loss (M=1): 1.7136 | LR: 0.009077 | Path noti: 254
# Epoch 118 | Batch  125 | Loss (M=1): 1.6453 | LR: 0.009077 | Path noti: 254
# Epoch 118 | Batch  150 | Loss (M=1): 1.6670 | LR: 0.009077 | Path noti: 254
# Epoch 118 | Batch  175 | Loss (M=1): 1.7306 | LR: 0.009077 | Path noti: 254
# Epoch 119 | Batch    0 | Loss (M=1): 1.8669 | LR: 0.008889 | Path noti: 254
# Epoch 119 | Batch   25 | Loss (M=1): 1.7185 | LR: 0.008889 | Path noti: 254
# Epoch 119 | Batch   50 | Loss (M=1): 1.7345 | LR: 0.008889 | Path noti: 254
# Epoch 119 | Batch   75 | Loss (M=1): 1.6235 | LR: 0.008889 | Path noti: 254
# Epoch 119 | Batch  100 | Loss (M=1): 1.6730 | LR: 0.008889 | Path noti: 254
# Epoch 119 | Batch  125 | Loss (M=1): 2.0017 | LR: 0.008889 | Path noti: 254
# Epoch 119 | Batch  150 | Loss (M=1): 1.5860 | LR: 0.008889 | Path noti: 254
# Epoch 119 | Batch  175 | Loss (M=1): 1.7107 | LR: 0.008889 | Path noti: 254
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated
# evalutated

# %%
import os
import ast
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from nats_bench import create
from ws_universale.nb201 import networkdag_to_nb201_str
from dataset_loader import load_nas201_api, fetch_gt_accuracies
from utils_functions.plots_utils import compute_and_plot_correlation


BASE_DIR    = os.getcwd()
DATASET_DIR = "Deep-Learning-Project/datasets"

# %%
# ── cella 2: confronto con ground truth ───────────────────────────────────────

df_results = fetch_gt_accuracies(
    networks   = population,    # list[NetworkDAG] dalla cella 1
    accuracies = accuracies,    # list[float] dalla supernet
    dataset    = 'cifar10-valid',
    hp         = '200',
)

print(df_results[['arch_str','Accuracy','GT_Accuracy']].to_string())

correlations = compute_and_plot_correlation(df_results)
# Out:
# Caricamento NATS-Bench da: Deep-Learning-Project/datasets\NATS-tss-v1_0-3ffb9-simple
# Architetture trovate nel benchmark: 256/256
#                                                                                             arch_str  Accuracy  GT_Accuracy
# 0                    |none~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|skip_connect~2|     37.84    84.332000
# 1                            |none~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|     36.46    72.249333
# 2                    |none~0|+|none~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|     37.40    84.416000
# 3            |none~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|     36.15    71.092000
# 4            |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|     47.67    88.985333
# 5            |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|none~2|     46.38    87.724000
# 6                    |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|     40.59    88.040000
# 7                    |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|     46.68    88.640000
# 8            |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|     36.72    66.252000
# 9                            |skip_connect~0|+|none~0|none~1|+|skip_connect~0|nor_conv_1x1~1|none~2|     40.44    86.826000
# 10           |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|     43.82    89.858667
# 11           |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|none~2|     40.37    87.054667
# 12   |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|     38.83    85.384000
# 13           |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|     50.27    90.270000
# 14                   |skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|     42.47    89.020000
# 15   |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|     42.14    89.877333
# 16   |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|     45.72    86.202000
# 17   |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|     42.28    85.964000
# 18           |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|     46.94    87.613333
# 19                   |none~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|     36.88    84.664000
# 20           |none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|     40.58    84.800000
# 21                   |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|     39.65    80.764000
# 22           |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|     45.47    89.508000
# 23                   |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|none~2|     36.91    84.410667
# 24   |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|     41.75    87.420000
# 25           |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|     39.24    75.376000
# 26                   |nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|     49.40    89.465333
# 27                           |none~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_3x3~2|     39.66    88.690667
# 28           |none~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|     36.57    76.206667
# 29   |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|     40.59    83.828000
# 30   |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     41.99    89.204000
# 31                   |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|skip_connect~1|none~2|     36.98    78.217333
# 32           |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|     40.24    84.264000
# 33                                   |skip_connect~0|+|none~0|none~1|+|none~0|skip_connect~1|none~2|     37.08    84.274667
# 34                   |none~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|     42.24    86.528000
# 35   |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|     38.71    82.917333
# 36           |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|     41.04    88.760000
# 37           |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     47.04    89.826000
# 38                                   |none~0|+|none~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|     41.44    88.748000
# 39   |skip_connect~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|     39.96    74.692000
# 40           |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|none~2|     40.81    88.712000
# 41                           |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|avg_pool_3x3~1|none~2|     36.86    84.564000
# 42           |none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     40.38    88.836000
# 43                   |skip_connect~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|nor_conv_3x3~1|none~2|     42.47    89.074667
# 44   |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|     50.69    89.804000
# 45           |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|none~2|     40.23    89.057333
# 46                           |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|none~1|none~2|     40.45    86.602000
# 47           |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|none~2|     36.55    71.034667
# 48                           |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|avg_pool_3x3~1|none~2|     36.61    63.504000
# 49           |skip_connect~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|     39.69    83.397333
# 50                   |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|     41.64    75.685333
# 51   |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|     41.17    85.692000
# 52   |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|     44.98    90.902667
# 53                   |nor_conv_1x1~0|+|none~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|     41.22    88.170667
# 54                   |none~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|     34.17    84.389333
# 55           |skip_connect~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|     42.60    87.816000
# 56   |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|     40.34    82.305333
# 57                   |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_1x1~2|     38.46    75.554667
# 58                   |none~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|     31.89    84.540000
# 59   |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|     40.50    82.574000
# 60                   |nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|     50.24    88.898667
# 61                   |none~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|     37.49    84.582000
# 62                   |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|none~2|     36.89    71.100000
# 63                   |none~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|     36.30    71.666667
# 64           |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_1x1~2|     42.86    88.586667
# 65                   |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|none~2|     40.97    86.788000
# 66   |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|     45.37    85.813333
# 67           |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|     41.82    89.932000
# 68           |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_3x3~2|     47.24    90.822000
# 69           |none~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|     46.42    90.548000
# 70           |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|none~0|skip_connect~1|nor_conv_3x3~2|     39.90    88.906000
# 71           |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|     44.70    87.394667
# 72                   |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|none~1|nor_conv_1x1~2|     48.67    87.244000
# 73                   |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|     39.45    79.210667
# 74   |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|     45.88    88.918000
# 75                   |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|     36.50    84.600000
# 76           |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|     46.76    87.394000
# 77                   |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|     50.50    88.828000
# 78   |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     47.26    89.341333
# 79   |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|     46.23    89.866000
# 80   |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|     41.08    82.966667
# 81           |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|     38.74    87.201333
# 82   |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|     42.50    88.822000
# 83           |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|     41.59    82.536000
# 84           |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|     40.80    86.906000
# 85                   |skip_connect~0|+|skip_connect~0|none~1|+|none~0|skip_connect~1|nor_conv_3x3~2|     38.83    89.168000
# 86           |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|     42.59    86.180000
# 87           |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|none~2|     39.15    89.218000
# 88           |none~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|     47.37    90.932000
# 89                   |none~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|     36.72    72.256000
# 90   |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     48.85    88.832000
# 91   |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|     42.22    77.898667
# 92   |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|     50.32    90.662000
# 93           |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|     47.11    89.910000
# 94           |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|     40.31    85.636000
# 95   |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|     39.72    75.277333
# 96           |none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|     46.98    89.885333
# 97           |nor_conv_3x3~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|     48.57    89.320000
# 98                   |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|     41.14    88.170000
# 99   |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|     45.79    86.080000
# 100  |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|     42.96    89.669333
# 101          |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|     47.77    89.780000
# 102          |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|     40.97    83.116000
# 103                  |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|     40.08    87.850667
# 104          |skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|     42.14    89.325333
# 105  |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     50.77    89.900000
# 106                          |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|none~2|     38.08    82.632000
# 107                          |nor_conv_1x1~0|+|skip_connect~0|none~1|+|none~0|none~1|skip_connect~2|     37.22    84.554000
# 108          |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|skip_connect~2|     36.65    64.902667
# 109          |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|     50.60    90.874000
# 110          |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|skip_connect~2|     39.99    83.426000
# 111                  |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|     45.95    86.190000
# 112          |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|skip_connect~2|     38.44    88.340000
# 113                          |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|none~2|     10.00     9.712000
# 114          |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|     45.77    85.468000
# 115                  |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|     47.25    89.809333
# 116  |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|     40.66    88.488000
# 117  |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     46.53    89.301333
# 118          |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_1x1~2|     43.71    88.390000
# 119  |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|     47.13    88.358000
# 120          |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|     46.27    89.898000
# 121  |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|     41.03    86.952000
# 122                  |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|skip_connect~1|none~2|     40.51    85.498667
# 123  |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|     44.67    86.602000
# 124                  |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_1x1~1|skip_connect~2|     49.34    89.484000
# 125  |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     50.85    88.992000
# 126  |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|     41.75    86.472000
# 127  |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|     46.11    89.330000
# 128                  |none~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|skip_connect~2|     37.83    84.398000
# 129  |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|     40.54    83.166667
# 130          |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|     40.88    86.906000
# 131          |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|skip_connect~2|     44.45    87.688000
# 132                  |nor_conv_1x1~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|     46.16    86.340000
# 133                  |nor_conv_3x3~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     50.19    88.712000
# 134          |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_1x1~2|     48.82    91.056000
# 135                          |nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|     50.40    89.528000
# 136          |avg_pool_3x3~0|+|none~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|     39.51    77.188000
# 137                  |none~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|     36.42    70.128000
# 138  |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     41.64    79.388000
# 139  |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|     47.01    88.960000
# 140                  |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|skip_connect~1|skip_connect~2|     36.70    67.308000
# 141          |nor_conv_1x1~0|+|none~0|skip_connect~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|     40.32    87.021333
# 142                  |none~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|     40.59    87.772000
# 143          |nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|     49.47    90.432000
# 144          |nor_conv_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|     39.15    88.816000
# 145          |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|     46.71    89.866000
# 146                  |skip_connect~0|+|none~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|     40.32    87.116000
# 147          |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|     45.03    87.761333
# 148  |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     50.34    89.552000
# 149                  |none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|     40.93    86.266000
# 150                  |nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|     40.50    86.960000
# 151                  |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|     44.14    87.764000
# 152  |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|     45.01    85.980000
# 153          |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|     50.93    90.190667
# 154          |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|     46.79    89.024000
# 155                  |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|none~2|     47.39    87.854000
# 156          |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|     47.61    87.876000
# 157                  |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|     41.19    87.434000
# 158          |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|     42.93    88.560000
# 159  |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|     41.56    89.244000
# 160                  |nor_conv_3x3~0|+|none~0|none~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|     39.01    87.328000
# 161                  |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|     46.72    87.522667
# 162                  |skip_connect~0|+|none~0|nor_conv_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|     44.43    90.809333
# 163  |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     47.80    89.360000
# 164  |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|     41.27    84.186667
# 165          |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|     39.97    80.177333
# 166          |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|     47.16    86.702667
# 167  |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|     42.42    80.420000
# 168  |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|     47.06    88.593333
# 169  |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|     44.67    90.597333
# 170          |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|     46.44    90.124000
# 171          |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|skip_connect~1|avg_pool_3x3~2|     48.59    88.277333
# 172                  |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|     41.21    88.469333
# 173                  |nor_conv_3x3~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|none~2|     40.81    88.768000
# 174          |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|     50.68    89.120000
# 175  |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|     47.42    86.710000
# 176                  |none~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|     36.33    77.910000
# 177                          |none~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|skip_connect~2|     39.49    88.634000
# 178                          |nor_conv_1x1~0|+|none~0|none~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|     38.70    85.928000
# 179  |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|     45.42    89.182667
# 180          |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|skip_connect~1|none~2|     39.16    89.160000
# 181  |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|     41.76    82.672000
# 182  |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|     42.65    89.706667
# 183                  |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|     36.65    71.890000
# 184  |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|     49.49    90.094000
# 185          |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|     50.39    89.554000
# 186  |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|     42.67    87.752000
# 187                  |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|     47.01    88.736000
# 188          |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|     40.63    84.665333
# 189  |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|     44.71    85.440000
# 190                          |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|     42.15    88.244000
# 191          |nor_conv_1x1~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|     45.33    89.578000
# 192  |skip_connect~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|     39.38    74.626667
# 193  |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|     42.01    87.978000
# 194                  |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|none~0|skip_connect~1|skip_connect~2|     46.92    88.494667
# 195                  |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|none~2|     48.54    87.132000
# 196          |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|     45.59    89.046667
# 197          |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|     46.11    88.942000
# 198          |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|     40.38    86.001333
# 199                  |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|skip_connect~2|     41.72    88.836000
# 200                                  |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|none~2|     41.75    88.674000
# 201  |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|     42.47    89.004000
# 202          |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|     42.21    86.968000
# 203          |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|     48.01    89.624000
# 204          |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|     40.69    86.948000
# 205          |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|     47.72    88.469333
# 206                  |skip_connect~0|+|none~0|nor_conv_3x3~1|+|none~0|skip_connect~1|avg_pool_3x3~2|     40.04    88.449333
# 207                  |none~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|     37.94    84.634000
# 208          |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|     36.49    58.698667
# 209          |skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|     38.78    86.036000
# 210          |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|none~2|     40.44    86.750667
# 211                  |none~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|     40.34    85.397333
# 212                  |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|none~1|skip_connect~2|     40.38    86.176000
# 213                  |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|     50.37    88.200000
# 214          |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|     46.40    85.534000
# 215          |skip_connect~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     40.22    86.568000
# 216                          |none~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|     41.04    88.810667
# 217                  |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|     49.63    88.666000
# 218          |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|     39.29    81.600000
# 219  |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|     43.84    84.086667
# 220                  |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|     42.13    88.722000
# 221  |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|     43.42    88.520000
# 222          |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|     47.53    89.710000
# 223  |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|     46.87    90.184000
# 224                                          |none~0|+|none~0|none~1|+|none~0|nor_conv_3x3~1|none~2|     10.00     9.712000
# 225          |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|     40.19    83.644000
# 226          |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|     44.26    89.168000
# 227                  |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|     40.20    85.969333
# 228  |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|     40.55    68.648000
# 229                  |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|     43.01    86.512000
# 230  |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|     40.19    68.288000
# 231                  |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|     40.56    84.134000
# 232          |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|skip_connect~2|     44.33    86.500000
# 233                  |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|skip_connect~1|none~2|     37.15    84.254667
# 234          |none~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     41.08    88.634000
# 235  |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|     46.21    87.138000
# 236                  |avg_pool_3x3~0|+|none~0|none~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|     37.16    78.264000
# 237                  |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|     38.46    88.982000
# 238  |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|     41.51    86.544000
# 239                  |none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|     38.39    81.762667
# 240          |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|     47.48    88.985333
# 241                  |avg_pool_3x3~0|+|none~0|none~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|     40.60    85.276000
# 242                  |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|none~2|     40.55    86.041333
# 243  |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|     48.00    90.712000
# 244          |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|     40.81    88.086667
# 245                          |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|     46.95    89.602000
# 246  |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|     43.90    88.674000
# 247                  |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|     41.32    88.288000
# 248                  |nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|none~1|skip_connect~2|     41.64    88.948000
# 249          |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|     48.80    88.354000
# 250          |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|none~2|     40.38    86.013333
# 251          |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|     39.45    71.980000
# 252          |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|none~0|skip_connect~1|nor_conv_1x1~2|     39.20    86.204000
# 253          |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|none~1|skip_connect~2|     36.67    65.954667
# 254  |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|     48.19    88.308000
# 255          |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|none~2|     42.13    86.992000
#
# ============================================================
#   CORRELAZIONE SUPERNET PROXY vs NB201 GROUND TRUTH
# ============================================================
#   Spearman ρ : +0.7097  (p = 0.0000)
#   Kendall  τ : +0.5151  (p = 0.0000)
#   Pearson  r : +0.7513  (p = 0.0000)
#   Campioni   : 256 architetture
# ============================================================

# %%
# df_results.to_csv('risultati_accuracies.csv', index=False)
